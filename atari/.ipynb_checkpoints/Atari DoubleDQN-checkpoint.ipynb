# %%
import torch
import torch.nn as nn

# Import the gym module
import gym
import numpy as np
import time 

from matplotlib import pyplot as plt

import random

import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

# %%
class NoopResetEnv(gym.Wrapper):
    def __init__(self, env, noop_max=10):
        '''첫 번째 트릭 No-Operation. 초기화 후 일정 단계에 이를때까지 아무 행동도 하지않고
        게임 초기 상태를 다양하게 하여 특정 시작 상태만 학습하는 것을 방지한다'''

        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def reset(self, **kwargs):
        """ Do no-op action for a number of steps in [1, noop_max]."""
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = self.unwrapped.np_random.randint(
                1, self.noop_max + 1)  # pylint: disable=E1101
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, done, _ = self.env.step(self.noop_action)
            if done:
                obs = self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)

# %%
# Create a breakout environment
env = gym.make('BreakoutNoFrameskip-v4')
env = NoopResetEnv(env, noop_max=30)

# %%
def preprocess(img):
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img = cv2.resize(img, (84, 84), interpolation=cv2.INTER_AREA)
    return np.expand_dims(img, 0) # (1, 80, 80)

# %%
env.reset()
img = plt.imshow(env.render(mode='rgb_array')) # only call this once
for _ in range(30):
    img.set_data(env.render(mode='rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    action = env.action_space.sample()
    env.step(action)

# %%
env.reset()
for _ in range(30):
    s, _, _, _ = env.step(env.action_space.sample())

plt.imshow(preprocess(s)[0])

# %%
from collections import deque
import random 

class ReplayMemory(object):
    def __init__(self, capacity):
        self.deque = deque(maxlen=capacity)

    def append(self, state, action, reward, next_state, done):
        self.deque.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        state, action, reward, next_state, done = zip(*random.sample(self.deque, batch_size))
        return np.concatenate(state), action, reward, np.concatenate(next_state), done
    
    def __len__(self):
        return len(self.deque)

# %%
class FrameHistory(object):
    # consecutive frame을 4개씩 병합하여 새로운 x를 하나씩 만드는 클래스
    # 만들어진 x는 4개씩 concat하고 s를 만들어서 DQN의 input으로 들어감
    def __init__(self, env, k=4):
        self.state_deque = deque(maxlen=k) # [x1, x2, x3, x4]
        self.frame_history_deque = deque(maxlen=k) #[s1, s2, s3, s4]
        self.k = k
        
        # 최초에는 초기 화면(env.reset)으로 채워둠
        self.env = env
        self.initial_state = self.preprocess(self.env.reset())
        self.reset()
        
    def preprocess(self, img):
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        img = cv2.resize(img, (84, 84), interpolation=cv2.INTER_AREA)
        return np.expand_dims(img, 0) # (1, 80, 80)
    
    def append_frame(self, s):
        # if full, aggregate and clear old frames, append new frame to history queue
        self.frame_history_deque.append(self.preprocess(s))
        
        if len(self) == self.k:
            self.state_deque.append(self.aggregate_frame())
        return
        
    def aggregate_frame(self):
        if len(self) < self.k:
            raise ValueError('not enough frames in history, expected %s, but got %s'%(self.k, len(self)))
        
        # element-wise maximum to aggregate
        frame_history = [self.frame_history_deque.popleft() for _ in range(self.k)]
        return np.maximum.reduce(frame_history[-2:]) #마지막 2 프레임 사용 
    
    def get_state(self):
        S = np.array([self.state_deque[i] for i in range(self.k)]) # S = [x1, x2, x3, x4], (4, 1, 80, 80)
        S = np.swapaxes(S, 0, 1) # (1, 4, 80, 80)
        return S
    
    def reset(self):
        self.frame_history_deque = deque(maxlen=k)
        self.state_deque = deque(maxlen=k)
        
        for _ in range(self.k):
            self.state_deque.append(self.initial_state)
    
    def __len__(self):
        return len(self.frame_history_deque)

# %%
class DQN(nn.Module):
    def __init__(self, in_dim, n_action):
        super(DQN, self).__init__()
        self.device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
        
        self.conv = nn.Sequential(
            nn.Conv2d(in_dim, 32, (8, 8), stride=4), nn.ReLU(), # conv 1
            nn.Conv2d(32, 64, (4, 4), stride=2), nn.ReLU(), # conv 2
            nn.Conv2d(64, 64, (3, 3), stride=1), nn.ReLU() # conv 3
        )
        self.fc = nn.Sequential(
            nn.Linear(64*7*7, 512), nn.ReLU(), # hidden layer
            nn.Linear(512, n_action)
        )
        
    def to_tensor(self, img):
        img = torch.tensor(img, dtype=torch.float32, device=self.device).cuda(non_blocking=True) # to tensor
        img /= 255                                   # normalize into 0-1
        while img.dim() < 4 :                        # 4-dim
            img = img.unsqueeze(0)
        return img
        
    def forward(self, frames):
        frames = self.to_tensor(frames) 
        conved = self.conv(frames)
        conved = conved.view(conved.size(0), -1)
        output = self.fc(conved)
        return output

# %%
import torch.nn.init as init

def weight_init(m):
    '''
    Usage:
        model = Model()
        model.apply(weight_init)
    '''
    if isinstance(m, nn.Conv2d):
        init.xavier_normal_(m.weight.data)
        if m.bias is not None:
            init.normal_(m.bias.data)

    elif isinstance(m, nn.Linear):
        init.xavier_normal_(m.weight.data)
        init.normal_(m.bias.data)
    return

# %%
#############
k = 4 ## number of skipped frame
#############

behavior_net = DQN(in_dim=k, n_action=4)
target_net = DQN(in_dim=k, n_action=4)

behavior_net.to(behavior_net.device) # model to cuda
target_net.to(target_net.device)     # model to cuda

behavior_net.apply(weight_init)
target_net.apply(weight_init)
# Out:
# DQN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=4, bias=True)
#   )
# )

# %%
def grow_batch_size(current_memory, max_memory):
    # grow batch size from 32 to 64 as respect to memory size
    memory_ratio = current_memory / max_memory
    new_batch_size = int(32 + 32*memory_ratio)
    return new_batch_size

# %%
class Fitter():
    def __init__(self, env, behavior_net, target_net, k=4, train_method='DQN'):
        self.env = env
        self.train_method = train_method
        self.device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

        # networks
        self.behavior_net = behavior_net
        self.target_net = target_net
        self.behavior_net.to(self.behavior_net.device) # model to cuda
        self.target_net.to(self.target_net.device)     # model to cuda
        
        # train parameters
        self.gamma = 0.99 #as written in paper
        self.criterion = nn.SmoothL1Loss() # huber loss (error-clipping)
        self.optim = torch.optim.RMSprop(self.behavior_net.parameters(), lr=0.00025, alpha=0.95, eps=0.01) #as written in paper in Rainbow
        self.k = k
        
        # train details
        self.total_frame = 0
        self.total_episode = 0
        
        self.test_e = 0.05
        self.batch_size = 32
        self.max_replay = 250000 # not as written in paper
        self.min_replay = 50000 # not as written in the paper
        self.replay_memory = ReplayMemory(self.max_replay)
        self.frame_history = FrameHistory(env=self.env, k=self.k)
        
        self.train_reward_ls = []
        self.test_reward_ls = []
    
    # train-epsilon
    @property
    def train_e(self):
        return np.max([1 - 9.0*1e-07*self.total_frame, 0.1])
    
    
    def reset_episode(self):
        # game(episode) begins
        self.env.reset()  
        self.frame_history.reset() #frame history reset
        self.current_episode_frame = 0         # each episode의 frame 수 
        self.current_episode_reward = 0        # each episode의 reward 합
        self.current_life = 5
    
    def choose_action(self, S, e):
        # at the beginning of an episode, do something
        if self.current_episode_frame == 0:
            a = 1
        else:
            # Choose an action by e-greedy
            if np.random.rand(1) < e :
                a = self.env.action_space.sample()
            else:
                q_behavior = self.behavior_net(S)
                a = torch.argmax(q_behavior).item()
        return a
    
    
    def run_k_frames(self, e):
        # choose action!
        S = self.frame_history.get_state()
        a = self.choose_action(S, e)
        r_sum = 0
        
        # repeat the action k-times
        for _ in range(self.k):
            s_next, r, done, info = self.env.step(a)
            self.frame_history.append_frame(s_next)
            r_sum += self.clip_reward(r) # store clipped reward for future training replay(experience)
            
            # accumulate history
            self.current_episode_frame += 1
            self.current_episode_reward += r
            
            # if episode(game) ends, return done(True)
            if done: 
                return done
            
        # concat last k-frames into a next state S_next
        S_next = self.frame_history.get_state()
        
        # Terminal when lose life
        if info['ale.lives'] < self.current_life:
            self.current_life = info['ale.lives']
            terminal = True
            self.replay_memory.append(S, a, r_sum, S_next, terminal) # save replay(experience)
        
        else:
            self.replay_memory.append(S, a, r_sum, S_next, done) # save replay(experience)
            
        return done

    
    def train(self, max_total_frame):
        while self.total_frame < max_total_frame :
            # episode starts!
            self.reset_episode()
            
            done = False
            while not done:
                done = self.run_k_frames(e=self.train_e)
                
                # training when enough replay-memory, every k-frames
                if len(self.replay_memory) > self.min_replay:
                    self.train_batch(self.batch_size)   
                    self.total_frame += self.k
                    
                    # update target_net every 10,000 updates
                    if self.total_frame%(self.k*10000)== 0 :
                        self.update_target()
                
            # single-episode(game) is now done
            # if not enough memory, save more
            if len(self.replay_memory) < self.min_replay:
                print('Not enough replay yet, expected more than %s, but %s instead'%(self.min_replay, len(self.replay_memory)))
            
            # if enough memory, print train result
            else:
                print('Train Episode :%s, Total Frame : %s, Train reward : %s,'%(self.total_episode, self.total_frame, self.current_episode_reward))
                self.total_episode += 1
                self.train_reward_ls.append(self.current_episode_reward)
            
                # testing, every 10 episodes when enough replay
                if self.total_episode%10 == 0:
                    self.test()           

    def train_batch(self, batch_size):
        # get mini-batch from replay-memory
        S, A, R, S_next, D = self.replay_memory.sample(batch_size)
        A = self.to_tensor(A, dtype=torch.long)
        R = self.to_tensor(R, dtype=torch.float32)
        D = self.to_tensor(D, dtype=torch.float32)
        
        q_behaviors = self.behavior_net(S)                # Q-values for every possible actions
        q_behavior = self.select_indices(q_behaviors, A) # select Q-value for given actions
        
        if self.train_method=='DQN':
            q_targets_next = self.target_net(S_next)   # Q-values of every possible actions next state (targetDQN)
            q_target_next = q_targets_next.max(1)[0]   # max Q-values of next state
            q_target = R + self.gamma*q_target_next*(1-D) 
        
        elif self.train_method=='DoubleDQN':
            next_actions = torch.argmax(self.behavior_net(S_next), dim=1) # choose argmax behavior actions at S_next
            
            q_targets_next = self.target_net(S_next) # cal Q-values of every possible actions next state (targetDQN)
            q_target_next = self.select_indices(q_targets_next, next_actions) # select Q-value for next behavior actions
            q_target = R + self.gamma*q_target_next*(1-D)
        
        # update weights
        self.optim.zero_grad()
        loss = self.criterion(q_target, q_behavior)
        loss.backward()
        self.optim.step()
        return
        
    def to_tensor(self, x, dtype=torch.float):
        return torch.tensor(x, dtype=dtype, device=self.device)
    
    def select_indices(self, tensor, indices, dim=1):
        if type(indices) != torch.Tensor:
            indices = self.to_tensor(indices, dtype=torch.long)
        if indices.dim() < 2 :
            indices = indices.unsqueeze(1)
        return tensor.gather(dim, indices).squeeze(1)
    
    def clip_reward(self, r):
        return np.sign(r)
    
    
    def update_target(self):
        print('Update Target')
        self.target_net.load_state_dict(self.behavior_net.state_dict())
        return 
    
    def test(self):
        self.reset_episode()
        done=False
        while not done:
            done = self.run_k_frames(e=fitter.test_e) # e-greedy
                
        self.test_reward_ls.append(self.current_episode_reward)
        print('※Test※ \t Frames: %s \t Score: %s'%(self.current_episode_frame, self.current_episode_reward))
        return

# %%
fitter = Fitter(env, behavior_net, target_net, k=k, train_method='DoubleDQN')

# %%
max_frame = 50000000
fitter.train(max_frame)
# Out:
# Train Episode :8750, Total Frame : 11006704, Train reward : 41.0,
# Train Episode :8751, Total Frame : 11011076, Train reward : 41.0,
# Train Episode :8752, Total Frame : 11015184, Train reward : 55.0,
# Train Episode :8753, Total Frame : 11019468, Train reward : 37.0,
# Train Episode :8754, Total Frame : 11022980, Train reward : 23.0,
# Train Episode :8755, Total Frame : 11027244, Train reward : 51.0,
# Train Episode :8756, Total Frame : 11030376, Train reward : 25.0,
# Train Episode :8757, Total Frame : 11033828, Train reward : 23.0,
# Train Episode :8758, Total Frame : 11037732, Train reward : 43.0,
# Update Target
# Train Episode :8759, Total Frame : 11040836, Train reward : 25.0,
# ※Test※ 	 Frames: 4221 	 Score: 32.0
# Train Episode :8760, Total Frame : 11045896, Train reward : 53.0,
# Train Episode :8761, Total Frame : 11049524, Train reward : 31.0,
# Train Episode :8762, Total Frame : 11051928, Train reward : 20.0,
# Train Episode :8763, Total Frame : 11054520, Train reward : 38.0,
# Train Episode :8764, Total Frame : 11058104, Train reward : 30.0,
# Train Episode :8765, Total Frame : 11061728, Train reward : 29.0,
# Train Episode :8766, Total Frame : 11064728, Train reward : 29.0,
# Train Episode :8767, Total Frame : 11069928, Train reward : 60.0,
# Train Episode :8768, Total Frame : 11074844, Train reward : 37.0,
# Train Episode :8769, Total Frame : 11077196, Train reward : 16.0,
# ※Test※ 	 Frames: 1997 	 Score: 14.0
# Train Episode :8770, Total Frame : 11079368, Train reward : 13.0,
# Update Target
# Train Episode :8771, Total Frame : 11081848, Train reward : 20.0,
# Train Episode :8772, Total Frame : 11085616, Train reward : 42.0,
# Train Episode :8773, Total Frame : 11089780, Train reward : 35.0,
# Train Episode :8774, Total Frame : 11094292, Train reward : 37.0,
# Train Episode :8775, Total Frame : 11097472, Train reward : 23.0,
# Train Episode :8776, Total Frame : 11100720, Train reward : 26.0,
# Train Episode :8777, Total Frame : 11104088, Train reward : 41.0,
# Train Episode :8778, Total Frame : 11107528, Train reward : 30.0,
# Train Episode :8779, Total Frame : 11112672, Train reward : 51.0,
# ※Test※ 	 Frames: 4114 	 Score: 35.0
# Train Episode :8780, Total Frame : 11116776, Train reward : 40.0,
# Update Target
# Train Episode :8781, Total Frame : 11120908, Train reward : 28.0,
# Train Episode :8782, Total Frame : 11123436, Train reward : 21.0,
# Train Episode :8783, Total Frame : 11128864, Train reward : 78.0,
# Train Episode :8784, Total Frame : 11132028, Train reward : 22.0,
# Train Episode :8785, Total Frame : 11137984, Train reward : 68.0,
# Train Episode :8786, Total Frame : 11142408, Train reward : 40.0,
# Train Episode :8787, Total Frame : 11147736, Train reward : 53.0,
# Train Episode :8788, Total Frame : 11151700, Train reward : 36.0,
# Train Episode :8789, Total Frame : 11154576, Train reward : 20.0,
# ※Test※ 	 Frames: 4681 	 Score: 42.0
# Train Episode :8790, Total Frame : 11159840, Train reward : 260.0,
# Update Target
# Train Episode :8791, Total Frame : 11164084, Train reward : 43.0,
# Train Episode :8792, Total Frame : 11168132, Train reward : 33.0,
# Train Episode :8793, Total Frame : 11170852, Train reward : 30.0,
# Train Episode :8794, Total Frame : 11174412, Train reward : 35.0,
# Train Episode :8795, Total Frame : 11178396, Train reward : 37.0,
# Train Episode :8796, Total Frame : 11182016, Train reward : 29.0,
# Train Episode :8797, Total Frame : 11186000, Train reward : 41.0,
# Train Episode :8798, Total Frame : 11189484, Train reward : 25.0,
# Train Episode :8799, Total Frame : 11192408, Train reward : 18.0,
# ※Test※ 	 Frames: 3954 	 Score: 35.0
# Train Episode :8800, Total Frame : 11195360, Train reward : 25.0,
# Train Episode :8801, Total Frame : 11198500, Train reward : 29.0,
# Update Target
# Train Episode :8802, Total Frame : 11204460, Train reward : 58.0,
# Train Episode :8803, Total Frame : 11208540, Train reward : 41.0,
# Train Episode :8804, Total Frame : 11211796, Train reward : 36.0,
# Train Episode :8805, Total Frame : 11216448, Train reward : 51.0,
# Train Episode :8806, Total Frame : 11220016, Train reward : 25.0,
# Train Episode :8807, Total Frame : 11223716, Train reward : 32.0,
# Train Episode :8808, Total Frame : 11226552, Train reward : 24.0,
# Train Episode :8809, Total Frame : 11229848, Train reward : 25.0,
# ※Test※ 	 Frames: 3506 	 Score: 35.0
# Train Episode :8810, Total Frame : 11234636, Train reward : 48.0,
# Train Episode :8811, Total Frame : 11239832, Train reward : 65.0,
# Update Target
# Train Episode :8812, Total Frame : 11244200, Train reward : 39.0,
# Train Episode :8813, Total Frame : 11248200, Train reward : 65.0,
# Train Episode :8814, Total Frame : 11251468, Train reward : 31.0,
# Train Episode :8815, Total Frame : 11255212, Train reward : 29.0,
# Train Episode :8816, Total Frame : 11257388, Train reward : 19.0,
# Train Episode :8817, Total Frame : 11261236, Train reward : 54.0,
# Train Episode :8818, Total Frame : 11265356, Train reward : 27.0,
# Train Episode :8819, Total Frame : 11269992, Train reward : 62.0,
# ※Test※ 	 Frames: 4972 	 Score: 54.0
# Train Episode :8820, Total Frame : 11274136, Train reward : 35.0,
# Train Episode :8821, Total Frame : 11279196, Train reward : 44.0,
# Update Target
# Train Episode :8822, Total Frame : 11283196, Train reward : 30.0,
# Train Episode :8823, Total Frame : 11286048, Train reward : 20.0,
# Train Episode :8824, Total Frame : 11290676, Train reward : 49.0,
# Train Episode :8825, Total Frame : 11295936, Train reward : 58.0,
# Train Episode :8826, Total Frame : 11299752, Train reward : 38.0,
# Train Episode :8827, Total Frame : 11303052, Train reward : 35.0,
# Train Episode :8828, Total Frame : 11308260, Train reward : 42.0,
# Train Episode :8829, Total Frame : 11311064, Train reward : 23.0,
# ※Test※ 	 Frames: 4500 	 Score: 37.0
# Train Episode :8830, Total Frame : 11315376, Train reward : 41.0,
# Update Target
# Train Episode :8831, Total Frame : 11321068, Train reward : 64.0,
# Train Episode :8832, Total Frame : 11326076, Train reward : 68.0,
# Train Episode :8833, Total Frame : 11330156, Train reward : 40.0,
# Train Episode :8834, Total Frame : 11334440, Train reward : 53.0,
# Train Episode :8835, Total Frame : 11339696, Train reward : 61.0,
# Train Episode :8836, Total Frame : 11344448, Train reward : 43.0,
# Train Episode :8837, Total Frame : 11349244, Train reward : 48.0,
# Train Episode :8838, Total Frame : 11352660, Train reward : 25.0,
# Train Episode :8839, Total Frame : 11357304, Train reward : 53.0,
# ※Test※ 	 Frames: 5009 	 Score: 50.0
# Train Episode :8840, Total Frame : 11359896, Train reward : 32.0,
# Update Target
# Train Episode :8841, Total Frame : 11363352, Train reward : 41.0,
# Train Episode :8842, Total Frame : 11364644, Train reward : 6.0,
# Train Episode :8843, Total Frame : 11368456, Train reward : 32.0,
# Train Episode :8844, Total Frame : 11371768, Train reward : 41.0,
# Train Episode :8845, Total Frame : 11376656, Train reward : 58.0,
# Train Episode :8846, Total Frame : 11382128, Train reward : 51.0,
# Train Episode :8847, Total Frame : 11384680, Train reward : 21.0,
# Train Episode :8848, Total Frame : 11389104, Train reward : 40.0,
# Train Episode :8849, Total Frame : 11392148, Train reward : 25.0,
# ※Test※ 	 Frames: 5841 	 Score: 67.0
# Train Episode :8850, Total Frame : 11394944, Train reward : 23.0,
# Update Target
# Train Episode :8851, Total Frame : 11400244, Train reward : 70.0,
# Train Episode :8852, Total Frame : 11403840, Train reward : 31.0,
# Train Episode :8853, Total Frame : 11407048, Train reward : 26.0,
# Train Episode :8854, Total Frame : 11411836, Train reward : 41.0,
# Train Episode :8855, Total Frame : 11414920, Train reward : 53.0,
# Train Episode :8856, Total Frame : 11418136, Train reward : 39.0,
# Train Episode :8857, Total Frame : 11422648, Train reward : 41.0,
# Train Episode :8858, Total Frame : 11426388, Train reward : 56.0,
# Train Episode :8859, Total Frame : 11428740, Train reward : 30.0,
# ※Test※ 	 Frames: 4003 	 Score: 35.0
# Train Episode :8860, Total Frame : 11431992, Train reward : 23.0,
# Train Episode :8861, Total Frame : 11436216, Train reward : 38.0,
# Train Episode :8862, Total Frame : 11438820, Train reward : 22.0,
# Update Target
# Train Episode :8863, Total Frame : 11441820, Train reward : 48.0,
# Train Episode :8864, Total Frame : 11446624, Train reward : 53.0,
# Train Episode :8865, Total Frame : 11450796, Train reward : 42.0,
# Train Episode :8866, Total Frame : 11454984, Train reward : 40.0,
# Train Episode :8867, Total Frame : 11458668, Train reward : 32.0,
# Train Episode :8868, Total Frame : 11461728, Train reward : 28.0,
# Train Episode :8869, Total Frame : 11465688, Train reward : 41.0,
# ※Test※ 	 Frames: 4694 	 Score: 45.0
# Train Episode :8870, Total Frame : 11469128, Train reward : 35.0,
# Train Episode :8871, Total Frame : 11474032, Train reward : 54.0,
# Train Episode :8872, Total Frame : 11476580, Train reward : 28.0,
# Update Target
# Train Episode :8873, Total Frame : 11480056, Train reward : 51.0,
# Train Episode :8874, Total Frame : 11483816, Train reward : 35.0,
# Train Episode :8875, Total Frame : 11486344, Train reward : 26.0,
# Train Episode :8876, Total Frame : 11492128, Train reward : 66.0,
# Train Episode :8877, Total Frame : 11494788, Train reward : 25.0,
# Train Episode :8878, Total Frame : 11497820, Train reward : 35.0,
# Train Episode :8879, Total Frame : 11502028, Train reward : 42.0,
# ※Test※ 	 Frames: 4480 	 Score: 45.0
# Train Episode :8880, Total Frame : 11506944, Train reward : 52.0,
# Train Episode :8881, Total Frame : 11510208, Train reward : 37.0,
# Train Episode :8882, Total Frame : 11514236, Train reward : 45.0,
# Train Episode :8883, Total Frame : 11518776, Train reward : 55.0,
# Update Target
# Train Episode :8884, Total Frame : 11524048, Train reward : 52.0,
# Train Episode :8885, Total Frame : 11529064, Train reward : 52.0,
# Train Episode :8886, Total Frame : 11533380, Train reward : 42.0,
# Train Episode :8887, Total Frame : 11537896, Train reward : 41.0,
# Train Episode :8888, Total Frame : 11541748, Train reward : 41.0,
# Train Episode :8889, Total Frame : 11547164, Train reward : 49.0,
# ※Test※ 	 Frames: 5268 	 Score: 55.0
# Train Episode :8890, Total Frame : 11550992, Train reward : 43.0,
# Train Episode :8891, Total Frame : 11554776, Train reward : 31.0,
# Train Episode :8892, Total Frame : 11559308, Train reward : 190.0,
# Update Target
# Train Episode :8893, Total Frame : 11563636, Train reward : 31.0,
# Train Episode :8894, Total Frame : 11567028, Train reward : 35.0,
# Train Episode :8895, Total Frame : 11572020, Train reward : 58.0,
# Train Episode :8896, Total Frame : 11576876, Train reward : 42.0,
# Train Episode :8897, Total Frame : 11579852, Train reward : 23.0,
# Train Episode :8898, Total Frame : 11584172, Train reward : 56.0,
# Train Episode :8899, Total Frame : 11586456, Train reward : 27.0,
# ※Test※ 	 Frames: 3878 	 Score: 36.0
# Train Episode :8900, Total Frame : 11591088, Train reward : 40.0,
# Train Episode :8901, Total Frame : 11595880, Train reward : 57.0,
# Train Episode :8902, Total Frame : 11599912, Train reward : 48.0,
# Update Target
# Train Episode :8903, Total Frame : 11602424, Train reward : 17.0,
# Train Episode :8904, Total Frame : 11604860, Train reward : 25.0,
# Train Episode :8905, Total Frame : 11609632, Train reward : 49.0,
# Train Episode :8906, Total Frame : 11612524, Train reward : 32.0,
# Train Episode :8907, Total Frame : 11616584, Train reward : 45.0,
# Train Episode :8908, Total Frame : 11619256, Train reward : 27.0,
# Train Episode :8909, Total Frame : 11622368, Train reward : 24.0,
# ※Test※ 	 Frames: 4614 	 Score: 53.0
# Train Episode :8910, Total Frame : 11627124, Train reward : 52.0,
# Train Episode :8911, Total Frame : 11630280, Train reward : 36.0,
# Train Episode :8912, Total Frame : 11634004, Train reward : 59.0,
# Train Episode :8913, Total Frame : 11637976, Train reward : 35.0,
# Update Target
# Train Episode :8914, Total Frame : 11640964, Train reward : 26.0,
# Train Episode :8915, Total Frame : 11643708, Train reward : 30.0,
# Train Episode :8916, Total Frame : 11647896, Train reward : 39.0,
# Train Episode :8917, Total Frame : 11652336, Train reward : 47.0,
# Train Episode :8918, Total Frame : 11656864, Train reward : 51.0,
# Train Episode :8919, Total Frame : 11660196, Train reward : 29.0,
# ※Test※ 	 Frames: 3167 	 Score: 27.0
# Train Episode :8920, Total Frame : 11665980, Train reward : 54.0,
# Train Episode :8921, Total Frame : 11668812, Train reward : 29.0,
# Train Episode :8922, Total Frame : 11674228, Train reward : 56.0,
# Train Episode :8923, Total Frame : 11677108, Train reward : 23.0,
# Update Target
# Train Episode :8924, Total Frame : 11681832, Train reward : 61.0,
# Train Episode :8925, Total Frame : 11685396, Train reward : 29.0,
# Train Episode :8926, Total Frame : 11688104, Train reward : 16.0,
# Train Episode :8927, Total Frame : 11693648, Train reward : 49.0,
# Train Episode :8928, Total Frame : 11697488, Train reward : 42.0,
# Train Episode :8929, Total Frame : 11701664, Train reward : 47.0,
# ※Test※ 	 Frames: 3416 	 Score: 38.0
# Train Episode :8930, Total Frame : 11705996, Train reward : 40.0,
# Train Episode :8931, Total Frame : 11711844, Train reward : 75.0,
# Train Episode :8932, Total Frame : 11714112, Train reward : 35.0,
# Train Episode :8933, Total Frame : 11718296, Train reward : 36.0,
# Update Target
# Train Episode :8934, Total Frame : 11721028, Train reward : 31.0,
# Train Episode :8935, Total Frame : 11724872, Train reward : 46.0,
# Train Episode :8936, Total Frame : 11728304, Train reward : 22.0,
# Train Episode :8937, Total Frame : 11732224, Train reward : 52.0,
# Train Episode :8938, Total Frame : 11736424, Train reward : 45.0,
# Train Episode :8939, Total Frame : 11740820, Train reward : 45.0,
# ※Test※ 	 Frames: 3051 	 Score: 38.0
# Train Episode :8940, Total Frame : 11744008, Train reward : 36.0,
# Train Episode :8941, Total Frame : 11748076, Train reward : 55.0,
# Train Episode :8942, Total Frame : 11751684, Train reward : 41.0,
# Train Episode :8943, Total Frame : 11753552, Train reward : 17.0,
# Train Episode :8944, Total Frame : 11758176, Train reward : 39.0,
# Update Target
# Train Episode :8945, Total Frame : 11762848, Train reward : 41.0,
# Train Episode :8946, Total Frame : 11766884, Train reward : 40.0,
# Train Episode :8947, Total Frame : 11772080, Train reward : 57.0,
# Train Episode :8948, Total Frame : 11777796, Train reward : 46.0,
# Train Episode :8949, Total Frame : 11781220, Train reward : 38.0,
# ※Test※ 	 Frames: 2708 	 Score: 153.0
# Train Episode :8950, Total Frame : 11784640, Train reward : 36.0,
# Train Episode :8951, Total Frame : 11789824, Train reward : 46.0,
# Train Episode :8952, Total Frame : 11794532, Train reward : 79.0,
# Train Episode :8953, Total Frame : 11798640, Train reward : 54.0,
# Update Target
# Train Episode :8954, Total Frame : 11801816, Train reward : 29.0,
# Train Episode :8955, Total Frame : 11806036, Train reward : 28.0,
# Train Episode :8956, Total Frame : 11809228, Train reward : 33.0,
# Train Episode :8957, Total Frame : 11812116, Train reward : 21.0,
# Train Episode :8958, Total Frame : 11817256, Train reward : 63.0,
# Train Episode :8959, Total Frame : 11820668, Train reward : 35.0,
# ※Test※ 	 Frames: 3921 	 Score: 43.0
# Train Episode :8960, Total Frame : 11825436, Train reward : 50.0,
# Train Episode :8961, Total Frame : 11828412, Train reward : 31.0,
# Train Episode :8962, Total Frame : 11832524, Train reward : 39.0,
# Train Episode :8963, Total Frame : 11835464, Train reward : 23.0,
# Update Target
# Train Episode :8964, Total Frame : 11840932, Train reward : 61.0,
# Train Episode :8965, Total Frame : 11845004, Train reward : 48.0,
# Train Episode :8966, Total Frame : 11848840, Train reward : 38.0,
# Train Episode :8967, Total Frame : 11852220, Train reward : 23.0,
# Train Episode :8968, Total Frame : 11857332, Train reward : 53.0,
# Train Episode :8969, Total Frame : 11862240, Train reward : 48.0,
# ※Test※ 	 Frames: 4168 	 Score: 39.0
# Train Episode :8970, Total Frame : 11866884, Train reward : 54.0,
# Train Episode :8971, Total Frame : 11871440, Train reward : 59.0,
# Train Episode :8972, Total Frame : 11875896, Train reward : 45.0,
# Update Target
# Train Episode :8973, Total Frame : 11880640, Train reward : 48.0,
# Train Episode :8974, Total Frame : 11885600, Train reward : 53.0,
# Train Episode :8975, Total Frame : 11888772, Train reward : 30.0,
# Train Episode :8976, Total Frame : 11892700, Train reward : 40.0,
# Train Episode :8977, Total Frame : 11897504, Train reward : 55.0,
# Train Episode :8978, Total Frame : 11901508, Train reward : 44.0,
# Train Episode :8979, Total Frame : 11904264, Train reward : 23.0,
# ※Test※ 	 Frames: 5083 	 Score: 47.0
# Train Episode :8980, Total Frame : 11908144, Train reward : 28.0,
# Train Episode :8981, Total Frame : 11912264, Train reward : 31.0,
# Train Episode :8982, Total Frame : 11914760, Train reward : 24.0,
# Train Episode :8983, Total Frame : 11919552, Train reward : 52.0,
# Update Target
# Train Episode :8984, Total Frame : 11923100, Train reward : 26.0,
# Train Episode :8985, Total Frame : 11928608, Train reward : 55.0,
# Train Episode :8986, Total Frame : 11932828, Train reward : 81.0,
# Train Episode :8987, Total Frame : 11935548, Train reward : 19.0,
# Train Episode :8988, Total Frame : 11940340, Train reward : 80.0,
# Train Episode :8989, Total Frame : 11944648, Train reward : 27.0,
# ※Test※ 	 Frames: 3629 	 Score: 28.0
# Train Episode :8990, Total Frame : 11947692, Train reward : 40.0,
# Train Episode :8991, Total Frame : 11950384, Train reward : 26.0,
# Train Episode :8992, Total Frame : 11955600, Train reward : 56.0,
# Train Episode :8993, Total Frame : 11958468, Train reward : 21.0,
# Update Target
# Train Episode :8994, Total Frame : 11963204, Train reward : 36.0,
# Train Episode :8995, Total Frame : 11967640, Train reward : 55.0,
# Train Episode :8996, Total Frame : 11970788, Train reward : 32.0,
# Train Episode :8997, Total Frame : 11975784, Train reward : 46.0,
# Train Episode :8998, Total Frame : 11979096, Train reward : 47.0,
# Train Episode :8999, Total Frame : 11981188, Train reward : 24.0,
# ※Test※ 	 Frames: 4810 	 Score: 53.0
# Train Episode :9000, Total Frame : 11985488, Train reward : 35.0,
# Train Episode :9001, Total Frame : 11989500, Train reward : 38.0,
# Train Episode :9002, Total Frame : 11993720, Train reward : 38.0,
# Train Episode :9003, Total Frame : 11998576, Train reward : 52.0,
# Update Target
# Train Episode :9004, Total Frame : 12002436, Train reward : 46.0,
# Train Episode :9005, Total Frame : 12006472, Train reward : 51.0,
# Train Episode :9006, Total Frame : 12009928, Train reward : 28.0,
# Train Episode :9007, Total Frame : 12012592, Train reward : 24.0,
# Train Episode :9008, Total Frame : 12017288, Train reward : 40.0,
# Train Episode :9009, Total Frame : 12022028, Train reward : 44.0,
# ※Test※ 	 Frames: 4691 	 Score: 50.0
# Train Episode :9010, Total Frame : 12026408, Train reward : 52.0,
# Train Episode :9011, Total Frame : 12029932, Train reward : 42.0,
# Train Episode :9012, Total Frame : 12035312, Train reward : 54.0,
# Update Target
# Train Episode :9013, Total Frame : 12040432, Train reward : 51.0,
# Train Episode :9014, Total Frame : 12045856, Train reward : 54.0,
# Train Episode :9015, Total Frame : 12049968, Train reward : 41.0,
# Train Episode :9016, Total Frame : 12053048, Train reward : 30.0,
# Train Episode :9017, Total Frame : 12056732, Train reward : 43.0,
# Train Episode :9018, Total Frame : 12059828, Train reward : 26.0,
# Train Episode :9019, Total Frame : 12062896, Train reward : 35.0,
# ※Test※ 	 Frames: 3900 	 Score: 55.0
# Train Episode :9020, Total Frame : 12067120, Train reward : 32.0,
# Train Episode :9021, Total Frame : 12072256, Train reward : 54.0,
# Train Episode :9022, Total Frame : 12076128, Train reward : 43.0,
# Update Target
# Train Episode :9023, Total Frame : 12080248, Train reward : 41.0,
# Train Episode :9024, Total Frame : 12084836, Train reward : 68.0,
# Train Episode :9025, Total Frame : 12088992, Train reward : 42.0,
# Train Episode :9026, Total Frame : 12092796, Train reward : 37.0,
# Train Episode :9027, Total Frame : 12097296, Train reward : 48.0,
# Train Episode :9028, Total Frame : 12099964, Train reward : 18.0,
# Train Episode :9029, Total Frame : 12104332, Train reward : 48.0,
# ※Test※ 	 Frames: 4891 	 Score: 47.0
# Train Episode :9030, Total Frame : 12109364, Train reward : 59.0,
# Train Episode :9031, Total Frame : 12113444, Train reward : 39.0,
# Train Episode :9032, Total Frame : 12117428, Train reward : 32.0,
# Update Target
# Train Episode :9033, Total Frame : 12121808, Train reward : 38.0,
# Train Episode :9034, Total Frame : 12127124, Train reward : 52.0,
# Train Episode :9035, Total Frame : 12130212, Train reward : 30.0,
# Train Episode :9036, Total Frame : 12134224, Train reward : 42.0,
# Train Episode :9037, Total Frame : 12137680, Train reward : 33.0,
# Train Episode :9038, Total Frame : 12140712, Train reward : 71.0,
# Train Episode :9039, Total Frame : 12145800, Train reward : 54.0,
# ※Test※ 	 Frames: 4126 	 Score: 40.0
# Train Episode :9040, Total Frame : 12149844, Train reward : 45.0,
# Train Episode :9041, Total Frame : 12152552, Train reward : 21.0,
# Train Episode :9042, Total Frame : 12157656, Train reward : 70.0,
# Update Target
# Train Episode :9043, Total Frame : 12161836, Train reward : 44.0,
# Train Episode :9044, Total Frame : 12165892, Train reward : 45.0,
# Train Episode :9045, Total Frame : 12169968, Train reward : 46.0,
# Train Episode :9046, Total Frame : 12174124, Train reward : 34.0,
# Train Episode :9047, Total Frame : 12177668, Train reward : 29.0,
# Train Episode :9048, Total Frame : 12182188, Train reward : 57.0,
# Train Episode :9049, Total Frame : 12185456, Train reward : 47.0,
# ※Test※ 	 Frames: 3770 	 Score: 55.0
# Train Episode :9050, Total Frame : 12190904, Train reward : 92.0,
# Train Episode :9051, Total Frame : 12192820, Train reward : 12.0,
# Train Episode :9052, Total Frame : 12195552, Train reward : 25.0,
# Train Episode :9053, Total Frame : 12199160, Train reward : 35.0,
# Update Target
# Train Episode :9054, Total Frame : 12202580, Train reward : 43.0,
# Train Episode :9055, Total Frame : 12205972, Train reward : 43.0,
# Train Episode :9056, Total Frame : 12208236, Train reward : 30.0,
# Train Episode :9057, Total Frame : 12213956, Train reward : 56.0,
# Train Episode :9058, Total Frame : 12217860, Train reward : 40.0,
# Train Episode :9059, Total Frame : 12221768, Train reward : 31.0,
# ※Test※ 	 Frames: 3993 	 Score: 36.0
# Train Episode :9060, Total Frame : 12226756, Train reward : 54.0,
# Train Episode :9061, Total Frame : 12230916, Train reward : 47.0,
# Train Episode :9062, Total Frame : 12235876, Train reward : 50.0,
# Update Target
# Train Episode :9063, Total Frame : 12240272, Train reward : 45.0,
# Train Episode :9064, Total Frame : 12245420, Train reward : 74.0,
# Train Episode :9065, Total Frame : 12250584, Train reward : 57.0,
# Train Episode :9066, Total Frame : 12254824, Train reward : 41.0,
# Train Episode :9067, Total Frame : 12259160, Train reward : 48.0,
# Train Episode :9068, Total Frame : 12263652, Train reward : 60.0,
# Train Episode :9069, Total Frame : 12266708, Train reward : 28.0,
# ※Test※ 	 Frames: 3650 	 Score: 70.0
# Train Episode :9070, Total Frame : 12269404, Train reward : 26.0,
# Train Episode :9071, Total Frame : 12273676, Train reward : 48.0,
# Train Episode :9072, Total Frame : 12276528, Train reward : 25.0,
# Update Target
# Train Episode :9073, Total Frame : 12281136, Train reward : 38.0,
# Train Episode :9074, Total Frame : 12286332, Train reward : 53.0,
# Train Episode :9075, Total Frame : 12289920, Train reward : 30.0,
# Train Episode :9076, Total Frame : 12295244, Train reward : 57.0,
# Train Episode :9077, Total Frame : 12298008, Train reward : 23.0,
# Train Episode :9078, Total Frame : 12303652, Train reward : 78.0,
# Train Episode :9079, Total Frame : 12305860, Train reward : 11.0,
# ※Test※ 	 Frames: 4135 	 Score: 38.0
# Train Episode :9080, Total Frame : 12311832, Train reward : 57.0,
# Train Episode :9081, Total Frame : 12317140, Train reward : 52.0,
# Update Target
# Train Episode :9082, Total Frame : 12320348, Train reward : 36.0,
# Train Episode :9083, Total Frame : 12325608, Train reward : 50.0,
# Train Episode :9084, Total Frame : 12329220, Train reward : 31.0,
# Train Episode :9085, Total Frame : 12334744, Train reward : 57.0,
# Train Episode :9086, Total Frame : 12339848, Train reward : 48.0,
# Train Episode :9087, Total Frame : 12344628, Train reward : 39.0,
# Train Episode :9088, Total Frame : 12349032, Train reward : 48.0,
# Train Episode :9089, Total Frame : 12353760, Train reward : 50.0,
# ※Test※ 	 Frames: 5848 	 Score: 59.0
# Train Episode :9090, Total Frame : 12358004, Train reward : 59.0,
# Update Target
# Train Episode :9091, Total Frame : 12361684, Train reward : 37.0,
# Train Episode :9092, Total Frame : 12366412, Train reward : 40.0,
# Train Episode :9093, Total Frame : 12370184, Train reward : 32.0,
# Train Episode :9094, Total Frame : 12373448, Train reward : 36.0,
# Train Episode :9095, Total Frame : 12377720, Train reward : 49.0,
# Train Episode :9096, Total Frame : 12381724, Train reward : 54.0,
# Train Episode :9097, Total Frame : 12386112, Train reward : 41.0,
# Train Episode :9098, Total Frame : 12390524, Train reward : 33.0,
# Train Episode :9099, Total Frame : 12392976, Train reward : 17.0,
# ※Test※ 	 Frames: 4301 	 Score: 171.0
# Train Episode :9100, Total Frame : 12398392, Train reward : 66.0,
# Update Target
# Train Episode :9101, Total Frame : 12403488, Train reward : 50.0,
# Train Episode :9102, Total Frame : 12407300, Train reward : 33.0,
# Train Episode :9103, Total Frame : 12411224, Train reward : 35.0,
# Train Episode :9104, Total Frame : 12415804, Train reward : 44.0,
# Train Episode :9105, Total Frame : 12420144, Train reward : 40.0,
# Train Episode :9106, Total Frame : 12423628, Train reward : 36.0,
# Train Episode :9107, Total Frame : 12427648, Train reward : 35.0,
# Train Episode :9108, Total Frame : 12432688, Train reward : 46.0,
# Train Episode :9109, Total Frame : 12435740, Train reward : 53.0,
# ※Test※ 	 Frames: 4596 	 Score: 44.0
# Train Episode :9110, Total Frame : 12439488, Train reward : 34.0,
# Update Target
# Train Episode :9111, Total Frame : 12445436, Train reward : 74.0,
# Train Episode :9112, Total Frame : 12449456, Train reward : 36.0,
# Train Episode :9113, Total Frame : 12452760, Train reward : 38.0,
# Train Episode :9114, Total Frame : 12456896, Train reward : 42.0,
# Train Episode :9115, Total Frame : 12460772, Train reward : 29.0,
# Train Episode :9116, Total Frame : 12464772, Train reward : 38.0,
# Train Episode :9117, Total Frame : 12467928, Train reward : 30.0,
# Train Episode :9118, Total Frame : 12472824, Train reward : 46.0,
# Train Episode :9119, Total Frame : 12477348, Train reward : 43.0,
# ※Test※ 	 Frames: 4946 	 Score: 57.0
# Update Target
# Train Episode :9120, Total Frame : 12480600, Train reward : 33.0,
# Train Episode :9121, Total Frame : 12484716, Train reward : 37.0,
# Train Episode :9122, Total Frame : 12487976, Train reward : 19.0,
# Train Episode :9123, Total Frame : 12492136, Train reward : 46.0,
# Train Episode :9124, Total Frame : 12495204, Train reward : 23.0,
# Train Episode :9125, Total Frame : 12499676, Train reward : 46.0,
# Train Episode :9126, Total Frame : 12505316, Train reward : 52.0,
# Train Episode :9127, Total Frame : 12509124, Train reward : 57.0,
# Train Episode :9128, Total Frame : 12514492, Train reward : 58.0,
# Train Episode :9129, Total Frame : 12519208, Train reward : 47.0,
# ※Test※ 	 Frames: 4236 	 Score: 38.0
# Update Target
# Train Episode :9130, Total Frame : 12523108, Train reward : 49.0,
# Train Episode :9131, Total Frame : 12526516, Train reward : 265.0,
# Train Episode :9132, Total Frame : 12530240, Train reward : 35.0,
# Train Episode :9133, Total Frame : 12534204, Train reward : 41.0,
# Train Episode :9134, Total Frame : 12538660, Train reward : 60.0,
# Train Episode :9135, Total Frame : 12542708, Train reward : 38.0,
# Train Episode :9136, Total Frame : 12548752, Train reward : 78.0,
# Train Episode :9137, Total Frame : 12553236, Train reward : 53.0,
# Train Episode :9138, Total Frame : 12558704, Train reward : 50.0,
# Update Target
# Train Episode :9139, Total Frame : 12563180, Train reward : 39.0,
# ※Test※ 	 Frames: 5558 	 Score: 64.0
# Train Episode :9140, Total Frame : 12567740, Train reward : 46.0,
# Train Episode :9141, Total Frame : 12572856, Train reward : 42.0,
# Train Episode :9142, Total Frame : 12577208, Train reward : 42.0,
# Train Episode :9143, Total Frame : 12581764, Train reward : 44.0,
# Train Episode :9144, Total Frame : 12585692, Train reward : 50.0,
# Train Episode :9145, Total Frame : 12590772, Train reward : 44.0,
# Train Episode :9146, Total Frame : 12596060, Train reward : 56.0,
# Train Episode :9147, Total Frame : 12599648, Train reward : 46.0,
# Update Target
# Train Episode :9148, Total Frame : 12604792, Train reward : 53.0,
# Train Episode :9149, Total Frame : 12608852, Train reward : 41.0,
# ※Test※ 	 Frames: 4435 	 Score: 41.0
# Train Episode :9150, Total Frame : 12614640, Train reward : 69.0,
# Train Episode :9151, Total Frame : 12618412, Train reward : 29.0,
# Train Episode :9152, Total Frame : 12622336, Train reward : 41.0,
# Train Episode :9153, Total Frame : 12626188, Train reward : 29.0,
# Train Episode :9154, Total Frame : 12631776, Train reward : 58.0,
# Train Episode :9155, Total Frame : 12635848, Train reward : 48.0,
# Update Target
# Train Episode :9156, Total Frame : 12641196, Train reward : 63.0,
# Train Episode :9157, Total Frame : 12646536, Train reward : 68.0,
# Train Episode :9158, Total Frame : 12650616, Train reward : 42.0,
# Train Episode :9159, Total Frame : 12655928, Train reward : 61.0,
# ※Test※ 	 Frames: 4036 	 Score: 45.0
# Train Episode :9160, Total Frame : 12660872, Train reward : 47.0,
# Train Episode :9161, Total Frame : 12665976, Train reward : 65.0,
# Train Episode :9162, Total Frame : 12669684, Train reward : 40.0,
# Train Episode :9163, Total Frame : 12673048, Train reward : 39.0,
# Train Episode :9164, Total Frame : 12675968, Train reward : 22.0,
# Update Target
# Train Episode :9165, Total Frame : 12680632, Train reward : 41.0,
# Train Episode :9166, Total Frame : 12685212, Train reward : 48.0,
# Train Episode :9167, Total Frame : 12689480, Train reward : 41.0,
# Train Episode :9168, Total Frame : 12692500, Train reward : 28.0,
# Train Episode :9169, Total Frame : 12695120, Train reward : 21.0,
# ※Test※ 	 Frames: 6479 	 Score: 85.0
# Train Episode :9170, Total Frame : 12699684, Train reward : 38.0,
# Train Episode :9171, Total Frame : 12702184, Train reward : 32.0,
# Train Episode :9172, Total Frame : 12707448, Train reward : 46.0,
# Train Episode :9173, Total Frame : 12710612, Train reward : 28.0,
# Train Episode :9174, Total Frame : 12712752, Train reward : 39.0,
# Train Episode :9175, Total Frame : 12716940, Train reward : 43.0,
# Update Target
# Train Episode :9176, Total Frame : 12721596, Train reward : 57.0,
# Train Episode :9177, Total Frame : 12727024, Train reward : 51.0,
# Train Episode :9178, Total Frame : 12731868, Train reward : 52.0,
# Train Episode :9179, Total Frame : 12735720, Train reward : 63.0,
# ※Test※ 	 Frames: 5195 	 Score: 76.0
# Train Episode :9180, Total Frame : 12738612, Train reward : 33.0,
# Train Episode :9181, Total Frame : 12744812, Train reward : 62.0,
# Train Episode :9182, Total Frame : 12749640, Train reward : 54.0,
# Train Episode :9183, Total Frame : 12753624, Train reward : 30.0,
# Train Episode :9184, Total Frame : 12758576, Train reward : 59.0,
# Update Target
# Train Episode :9185, Total Frame : 12762708, Train reward : 38.0,
# Train Episode :9186, Total Frame : 12767128, Train reward : 54.0,
# Train Episode :9187, Total Frame : 12772304, Train reward : 65.0,
# Train Episode :9188, Total Frame : 12777568, Train reward : 61.0,
# Train Episode :9189, Total Frame : 12779728, Train reward : 33.0,
# ※Test※ 	 Frames: 5571 	 Score: 70.0
# Train Episode :9190, Total Frame : 12783916, Train reward : 42.0,
# Train Episode :9191, Total Frame : 12788148, Train reward : 45.0,
# Train Episode :9192, Total Frame : 12793388, Train reward : 56.0,
# Train Episode :9193, Total Frame : 12799308, Train reward : 62.0,
# Update Target
# Train Episode :9194, Total Frame : 12804040, Train reward : 37.0,
# Train Episode :9195, Total Frame : 12808152, Train reward : 38.0,
# Train Episode :9196, Total Frame : 12813480, Train reward : 58.0,
# Train Episode :9197, Total Frame : 12817672, Train reward : 36.0,
# Train Episode :9198, Total Frame : 12822344, Train reward : 54.0,
# Train Episode :9199, Total Frame : 12827960, Train reward : 88.0,
# ※Test※ 	 Frames: 5083 	 Score: 50.0
# Train Episode :9200, Total Frame : 12833096, Train reward : 62.0,
# Train Episode :9201, Total Frame : 12837644, Train reward : 44.0,
# Update Target
# Train Episode :9202, Total Frame : 12840964, Train reward : 51.0,
# Train Episode :9203, Total Frame : 12844164, Train reward : 25.0,
# Train Episode :9204, Total Frame : 12848208, Train reward : 36.0,
# Train Episode :9205, Total Frame : 12854312, Train reward : 72.0,
# Train Episode :9206, Total Frame : 12859436, Train reward : 48.0,
# Train Episode :9207, Total Frame : 12865868, Train reward : 77.0,
# Train Episode :9208, Total Frame : 12871160, Train reward : 54.0,
# Train Episode :9209, Total Frame : 12876160, Train reward : 61.0,
# ※Test※ 	 Frames: 4568 	 Score: 64.0
# Update Target
# Train Episode :9210, Total Frame : 12881176, Train reward : 44.0,
# Train Episode :9211, Total Frame : 12886264, Train reward : 61.0,
# Train Episode :9212, Total Frame : 12891148, Train reward : 49.0,
# Train Episode :9213, Total Frame : 12897960, Train reward : 91.0,
# Train Episode :9214, Total Frame : 12901968, Train reward : 33.0,
# Train Episode :9215, Total Frame : 12903880, Train reward : 10.0,
# Train Episode :9216, Total Frame : 12908260, Train reward : 48.0,
# Train Episode :9217, Total Frame : 12912864, Train reward : 48.0,
# Train Episode :9218, Total Frame : 12916868, Train reward : 46.0,
# Update Target
# Train Episode :9219, Total Frame : 12921620, Train reward : 50.0,
# ※Test※ 	 Frames: 5175 	 Score: 47.0
# Train Episode :9220, Total Frame : 12925144, Train reward : 26.0,
# Train Episode :9221, Total Frame : 12928848, Train reward : 32.0,
# Train Episode :9222, Total Frame : 12932696, Train reward : 53.0,
# Train Episode :9223, Total Frame : 12938272, Train reward : 56.0,
# Train Episode :9224, Total Frame : 12943664, Train reward : 68.0,
# Train Episode :9225, Total Frame : 12948660, Train reward : 52.0,
# Train Episode :9226, Total Frame : 12953256, Train reward : 74.0,
# Train Episode :9227, Total Frame : 12957804, Train reward : 43.0,
# Update Target
# Train Episode :9228, Total Frame : 12962144, Train reward : 40.0,
# Train Episode :9229, Total Frame : 12967448, Train reward : 55.0,
# ※Test※ 	 Frames: 5811 	 Score: 57.0
# Train Episode :9230, Total Frame : 12972072, Train reward : 46.0,
# Train Episode :9231, Total Frame : 12975768, Train reward : 43.0,
# Train Episode :9232, Total Frame : 12979912, Train reward : 41.0,
# Train Episode :9233, Total Frame : 12983204, Train reward : 22.0,
# Train Episode :9234, Total Frame : 12987612, Train reward : 59.0,
# Train Episode :9235, Total Frame : 12993760, Train reward : 87.0,
# Train Episode :9236, Total Frame : 12996716, Train reward : 43.0,
# Update Target
# Train Episode :9237, Total Frame : 13001340, Train reward : 42.0,
# Train Episode :9238, Total Frame : 13006520, Train reward : 52.0,
# Train Episode :9239, Total Frame : 13011636, Train reward : 58.0,
# ※Test※ 	 Frames: 3385 	 Score: 26.0
# Train Episode :9240, Total Frame : 13013828, Train reward : 18.0,
# Train Episode :9241, Total Frame : 13017480, Train reward : 32.0,
# Train Episode :9242, Total Frame : 13020428, Train reward : 35.0,
# Train Episode :9243, Total Frame : 13024736, Train reward : 56.0,
# Train Episode :9244, Total Frame : 13028304, Train reward : 22.0,
# Train Episode :9245, Total Frame : 13030620, Train reward : 27.0,
# Train Episode :9246, Total Frame : 13033660, Train reward : 48.0,
# Train Episode :9247, Total Frame : 13038280, Train reward : 44.0,
# Update Target
# Train Episode :9248, Total Frame : 13042628, Train reward : 78.0,
# Train Episode :9249, Total Frame : 13049064, Train reward : 111.0,
# ※Test※ 	 Frames: 5607 	 Score: 51.0
# Train Episode :9250, Total Frame : 13054712, Train reward : 59.0,
# Train Episode :9251, Total Frame : 13058912, Train reward : 43.0,
# Train Episode :9252, Total Frame : 13065392, Train reward : 86.0,
# Train Episode :9253, Total Frame : 13070108, Train reward : 50.0,
# Train Episode :9254, Total Frame : 13076460, Train reward : 72.0,
# Update Target
# Train Episode :9255, Total Frame : 13082428, Train reward : 80.0,
# Train Episode :9256, Total Frame : 13087540, Train reward : 43.0,
# Train Episode :9257, Total Frame : 13091176, Train reward : 27.0,
# Train Episode :9258, Total Frame : 13094052, Train reward : 24.0,
# Train Episode :9259, Total Frame : 13096512, Train reward : 43.0,
# ※Test※ 	 Frames: 3254 	 Score: 32.0
# Train Episode :9260, Total Frame : 13102216, Train reward : 74.0,
# Train Episode :9261, Total Frame : 13104028, Train reward : 13.0,
# Train Episode :9262, Total Frame : 13109420, Train reward : 60.0,
# Train Episode :9263, Total Frame : 13113096, Train reward : 33.0,
# Train Episode :9264, Total Frame : 13117612, Train reward : 35.0,
# Update Target
# Train Episode :9265, Total Frame : 13121304, Train reward : 35.0,
# Train Episode :9266, Total Frame : 13123748, Train reward : 35.0,
# Train Episode :9267, Total Frame : 13129224, Train reward : 53.0,
# Train Episode :9268, Total Frame : 13134736, Train reward : 60.0,
# Train Episode :9269, Total Frame : 13139804, Train reward : 47.0,
# ※Test※ 	 Frames: 4965 	 Score: 69.0
# Train Episode :9270, Total Frame : 13145268, Train reward : 62.0,
# Train Episode :9271, Total Frame : 13148464, Train reward : 29.0,
# Train Episode :9272, Total Frame : 13152764, Train reward : 36.0,
# Train Episode :9273, Total Frame : 13158360, Train reward : 79.0,
# Update Target
# Train Episode :9274, Total Frame : 13164220, Train reward : 60.0,
# Train Episode :9275, Total Frame : 13169928, Train reward : 84.0,
# Train Episode :9276, Total Frame : 13172492, Train reward : 29.0,
# Train Episode :9277, Total Frame : 13174912, Train reward : 22.0,
# Train Episode :9278, Total Frame : 13177404, Train reward : 34.0,
# Train Episode :9279, Total Frame : 13181108, Train reward : 35.0,
# ※Test※ 	 Frames: 5823 	 Score: 58.0
# Train Episode :9280, Total Frame : 13184944, Train reward : 42.0,
# Train Episode :9281, Total Frame : 13187444, Train reward : 14.0,
# Train Episode :9282, Total Frame : 13191308, Train reward : 36.0,
# Train Episode :9283, Total Frame : 13196384, Train reward : 46.0,
# Update Target
# Train Episode :9284, Total Frame : 13200464, Train reward : 37.0,
# Train Episode :9285, Total Frame : 13203764, Train reward : 27.0,
# Train Episode :9286, Total Frame : 13208048, Train reward : 44.0,
# Train Episode :9287, Total Frame : 13213012, Train reward : 52.0,
# Train Episode :9288, Total Frame : 13217948, Train reward : 56.0,
# Train Episode :9289, Total Frame : 13223524, Train reward : 63.0,
# ※Test※ 	 Frames: 5053 	 Score: 54.0
# Train Episode :9290, Total Frame : 13229684, Train reward : 66.0,
# Train Episode :9291, Total Frame : 13234688, Train reward : 59.0,
# Train Episode :9292, Total Frame : 13238672, Train reward : 45.0,
# Update Target
# Train Episode :9293, Total Frame : 13241940, Train reward : 49.0,
# Train Episode :9294, Total Frame : 13245948, Train reward : 35.0,
# Train Episode :9295, Total Frame : 13249292, Train reward : 25.0,
# Train Episode :9296, Total Frame : 13255056, Train reward : 74.0,
# Train Episode :9297, Total Frame : 13260168, Train reward : 67.0,
# Train Episode :9298, Total Frame : 13265480, Train reward : 66.0,
# Train Episode :9299, Total Frame : 13270680, Train reward : 51.0,
# ※Test※ 	 Frames: 6488 	 Score: 73.0
# Train Episode :9300, Total Frame : 13274384, Train reward : 48.0,
# Train Episode :9301, Total Frame : 13278940, Train reward : 43.0,
# Update Target
# Train Episode :9302, Total Frame : 13281476, Train reward : 23.0,
# Train Episode :9303, Total Frame : 13286672, Train reward : 52.0,
# Train Episode :9304, Total Frame : 13292664, Train reward : 71.0,
# Train Episode :9305, Total Frame : 13297036, Train reward : 49.0,
# Train Episode :9306, Total Frame : 13302508, Train reward : 48.0,
# Train Episode :9307, Total Frame : 13307400, Train reward : 46.0,
# Train Episode :9308, Total Frame : 13313156, Train reward : 67.0,
# Train Episode :9309, Total Frame : 13317364, Train reward : 47.0,
# ※Test※ 	 Frames: 3357 	 Score: 25.0
# Update Target
# Train Episode :9310, Total Frame : 13320380, Train reward : 23.0,
# Train Episode :9311, Total Frame : 13324176, Train reward : 44.0,
# Train Episode :9312, Total Frame : 13330160, Train reward : 286.0,
# Train Episode :9313, Total Frame : 13335616, Train reward : 61.0,
# Train Episode :9314, Total Frame : 13339360, Train reward : 37.0,
# Train Episode :9315, Total Frame : 13343844, Train reward : 36.0,
# Train Episode :9316, Total Frame : 13347064, Train reward : 21.0,
# Train Episode :9317, Total Frame : 13351844, Train reward : 44.0,
# Train Episode :9318, Total Frame : 13356676, Train reward : 44.0,
# Update Target
# Train Episode :9319, Total Frame : 13361152, Train reward : 57.0,
# ※Test※ 	 Frames: 3527 	 Score: 33.0
# Train Episode :9320, Total Frame : 13365104, Train reward : 36.0,
# Train Episode :9321, Total Frame : 13369164, Train reward : 36.0,
# Train Episode :9322, Total Frame : 13373472, Train reward : 49.0,
# Train Episode :9323, Total Frame : 13378776, Train reward : 53.0,
# Train Episode :9324, Total Frame : 13384828, Train reward : 58.0,
# Train Episode :9325, Total Frame : 13389956, Train reward : 46.0,
# Train Episode :9326, Total Frame : 13393968, Train reward : 44.0,
# Train Episode :9327, Total Frame : 13399468, Train reward : 72.0,
# Update Target
# Train Episode :9328, Total Frame : 13403500, Train reward : 37.0,
# Train Episode :9329, Total Frame : 13407176, Train reward : 38.0,
# ※Test※ 	 Frames: 5599 	 Score: 69.0
# Train Episode :9330, Total Frame : 13410908, Train reward : 42.0,
# Train Episode :9331, Total Frame : 13415808, Train reward : 51.0,
# Train Episode :9332, Total Frame : 13420228, Train reward : 38.0,
# Train Episode :9333, Total Frame : 13424308, Train reward : 40.0,
# Train Episode :9334, Total Frame : 13429188, Train reward : 53.0,
# Train Episode :9335, Total Frame : 13434504, Train reward : 73.0,
# Train Episode :9336, Total Frame : 13437972, Train reward : 35.0,
# Update Target
# Train Episode :9337, Total Frame : 13443020, Train reward : 59.0,
# Train Episode :9338, Total Frame : 13445228, Train reward : 17.0,
# Train Episode :9339, Total Frame : 13449132, Train reward : 27.0,
# ※Test※ 	 Frames: 6150 	 Score: 88.0
# Train Episode :9340, Total Frame : 13453612, Train reward : 52.0,
# Train Episode :9341, Total Frame : 13458016, Train reward : 46.0,
# Train Episode :9342, Total Frame : 13460964, Train reward : 21.0,
# Train Episode :9343, Total Frame : 13464936, Train reward : 40.0,
# Train Episode :9344, Total Frame : 13468636, Train reward : 29.0,
# Train Episode :9345, Total Frame : 13472604, Train reward : 33.0,
# Train Episode :9346, Total Frame : 13477324, Train reward : 45.0,
# Train Episode :9347, Total Frame : 13479476, Train reward : 16.0,
# Update Target
# Train Episode :9348, Total Frame : 13484516, Train reward : 52.0,
# Train Episode :9349, Total Frame : 13489336, Train reward : 44.0,
# ※Test※ 	 Frames: 4296 	 Score: 80.0
# Train Episode :9350, Total Frame : 13492696, Train reward : 24.0,
# Train Episode :9351, Total Frame : 13495516, Train reward : 18.0,
# Train Episode :9352, Total Frame : 13498876, Train reward : 29.0,
# Train Episode :9353, Total Frame : 13504068, Train reward : 65.0,
# Train Episode :9354, Total Frame : 13509688, Train reward : 67.0,
# Train Episode :9355, Total Frame : 13512584, Train reward : 38.0,
# Train Episode :9356, Total Frame : 13517276, Train reward : 62.0,
# Update Target
# Train Episode :9357, Total Frame : 13523476, Train reward : 73.0,
# Train Episode :9358, Total Frame : 13528396, Train reward : 59.0,
# Train Episode :9359, Total Frame : 13533620, Train reward : 56.0,
# ※Test※ 	 Frames: 4264 	 Score: 41.0
# Train Episode :9360, Total Frame : 13539288, Train reward : 90.0,
# Train Episode :9361, Total Frame : 13544396, Train reward : 49.0,
# Train Episode :9362, Total Frame : 13548088, Train reward : 43.0,
# Train Episode :9363, Total Frame : 13554212, Train reward : 88.0,
# Train Episode :9364, Total Frame : 13559380, Train reward : 44.0,
# Update Target
# Train Episode :9365, Total Frame : 13563724, Train reward : 53.0,
# Train Episode :9366, Total Frame : 13567528, Train reward : 33.0,
# Train Episode :9367, Total Frame : 13571340, Train reward : 30.0,
# Train Episode :9368, Total Frame : 13574480, Train reward : 31.0,
# Train Episode :9369, Total Frame : 13579532, Train reward : 55.0,
# ※Test※ 	 Frames: 5084 	 Score: 66.0
# Train Episode :9370, Total Frame : 13583760, Train reward : 47.0,
# Train Episode :9371, Total Frame : 13587884, Train reward : 45.0,
# Train Episode :9372, Total Frame : 13592432, Train reward : 53.0,
# Train Episode :9373, Total Frame : 13596464, Train reward : 47.0,
# Update Target
# Train Episode :9374, Total Frame : 13600592, Train reward : 52.0,
# Train Episode :9375, Total Frame : 13603964, Train reward : 25.0,
# Train Episode :9376, Total Frame : 13607556, Train reward : 35.0,
# Train Episode :9377, Total Frame : 13612724, Train reward : 74.0,
# Train Episode :9378, Total Frame : 13615820, Train reward : 38.0,
# Train Episode :9379, Total Frame : 13621264, Train reward : 64.0,
# ※Test※ 	 Frames: 6423 	 Score: 78.0
# Train Episode :9380, Total Frame : 13626316, Train reward : 69.0,
# Train Episode :9381, Total Frame : 13630364, Train reward : 77.0,
# Train Episode :9382, Total Frame : 13633104, Train reward : 19.0,
# Train Episode :9383, Total Frame : 13637764, Train reward : 64.0,
# Update Target
# Train Episode :9384, Total Frame : 13640512, Train reward : 31.0,
# Train Episode :9385, Total Frame : 13645620, Train reward : 52.0,
# Train Episode :9386, Total Frame : 13647792, Train reward : 13.0,
# Train Episode :9387, Total Frame : 13652980, Train reward : 50.0,
# Train Episode :9388, Total Frame : 13657648, Train reward : 34.0,
# Train Episode :9389, Total Frame : 13661884, Train reward : 44.0,
# ※Test※ 	 Frames: 5766 	 Score: 67.0
# Train Episode :9390, Total Frame : 13667200, Train reward : 52.0,
# Train Episode :9391, Total Frame : 13671276, Train reward : 43.0,
# Train Episode :9392, Total Frame : 13676952, Train reward : 62.0,
# Update Target
# Train Episode :9393, Total Frame : 13681888, Train reward : 68.0,
# Train Episode :9394, Total Frame : 13686540, Train reward : 43.0,
# Train Episode :9395, Total Frame : 13691700, Train reward : 58.0,
# Train Episode :9396, Total Frame : 13696708, Train reward : 45.0,
# Train Episode :9397, Total Frame : 13701864, Train reward : 58.0,
# Train Episode :9398, Total Frame : 13706424, Train reward : 50.0,
# Train Episode :9399, Total Frame : 13710996, Train reward : 50.0,
# ※Test※ 	 Frames: 3223 	 Score: 43.0
# Train Episode :9400, Total Frame : 13714080, Train reward : 30.0,
# Train Episode :9401, Total Frame : 13719752, Train reward : 60.0,
# Update Target
# Train Episode :9402, Total Frame : 13722992, Train reward : 24.0,
# Train Episode :9403, Total Frame : 13727132, Train reward : 54.0,
# Train Episode :9404, Total Frame : 13732320, Train reward : 72.0,
# Train Episode :9405, Total Frame : 13736632, Train reward : 56.0,
# Train Episode :9406, Total Frame : 13741212, Train reward : 46.0,
# Train Episode :9407, Total Frame : 13745764, Train reward : 39.0,
# Train Episode :9408, Total Frame : 13751488, Train reward : 68.0,
# Train Episode :9409, Total Frame : 13756068, Train reward : 41.0,
# ※Test※ 	 Frames: 4525 	 Score: 46.0
# Update Target
# Train Episode :9410, Total Frame : 13763044, Train reward : 94.0,
# Train Episode :9411, Total Frame : 13768296, Train reward : 62.0,
# Train Episode :9412, Total Frame : 13771532, Train reward : 23.0,
# Train Episode :9413, Total Frame : 13775608, Train reward : 55.0,
# Train Episode :9414, Total Frame : 13779856, Train reward : 39.0,
# Train Episode :9415, Total Frame : 13785728, Train reward : 77.0,
# Train Episode :9416, Total Frame : 13791756, Train reward : 114.0,
# Train Episode :9417, Total Frame : 13796752, Train reward : 59.0,
# Update Target
# Train Episode :9418, Total Frame : 13801864, Train reward : 72.0,
# Train Episode :9419, Total Frame : 13806476, Train reward : 58.0,
# ※Test※ 	 Frames: 4516 	 Score: 49.0
# Train Episode :9420, Total Frame : 13813028, Train reward : 75.0,
# Train Episode :9421, Total Frame : 13817624, Train reward : 58.0,
# Train Episode :9422, Total Frame : 13823160, Train reward : 68.0,
# Train Episode :9423, Total Frame : 13827408, Train reward : 45.0,
# Train Episode :9424, Total Frame : 13831596, Train reward : 46.0,
# ...
# Train Episode :9864, Total Frame : 15844772, Train reward : 28.0,
# Train Episode :9865, Total Frame : 15850116, Train reward : 67.0,
# Train Episode :9866, Total Frame : 15857072, Train reward : 259.0,
# Train Episode :9867, Total Frame : 15862104, Train reward : 82.0,
# Train Episode :9868, Total Frame : 15867048, Train reward : 54.0,
# Train Episode :9869, Total Frame : 15869676, Train reward : 19.0,
# ※Test※ 	 Frames: 5273 	 Score: 59.0
# Train Episode :9870, Total Frame : 15876640, Train reward : 90.0,
# Update Target
# Train Episode :9871, Total Frame : 15880052, Train reward : 27.0,
# Train Episode :9872, Total Frame : 15881852, Train reward : 13.0,
# Train Episode :9873, Total Frame : 15886484, Train reward : 56.0,
# Train Episode :9874, Total Frame : 15891104, Train reward : 57.0,
# Train Episode :9875, Total Frame : 15895584, Train reward : 60.0,
# Train Episode :9876, Total Frame : 15901504, Train reward : 84.0,
# Train Episode :9877, Total Frame : 15906416, Train reward : 50.0,
# Train Episode :9878, Total Frame : 15910056, Train reward : 38.0,
# Train Episode :9879, Total Frame : 15913476, Train reward : 44.0,
# ※Test※ 	 Frames: 5914 	 Score: 74.0
# Train Episode :9880, Total Frame : 15917296, Train reward : 34.0,
# Update Target
# Train Episode :9881, Total Frame : 15922040, Train reward : 43.0,
# Train Episode :9882, Total Frame : 15927596, Train reward : 59.0,
# Train Episode :9883, Total Frame : 15931028, Train reward : 34.0,
# Train Episode :9884, Total Frame : 15937404, Train reward : 92.0,
# Train Episode :9885, Total Frame : 15941588, Train reward : 61.0,
# Train Episode :9886, Total Frame : 15946056, Train reward : 51.0,
# Train Episode :9887, Total Frame : 15948696, Train reward : 27.0,
# Train Episode :9888, Total Frame : 15953392, Train reward : 48.0,
# Train Episode :9889, Total Frame : 15957656, Train reward : 59.0,
# ※Test※ 	 Frames: 4867 	 Score: 54.0
# Update Target
# Train Episode :9890, Total Frame : 15960728, Train reward : 37.0,
# Train Episode :9891, Total Frame : 15965112, Train reward : 40.0,
# Train Episode :9892, Total Frame : 15968140, Train reward : 30.0,
# Train Episode :9893, Total Frame : 15971072, Train reward : 19.0,
# Train Episode :9894, Total Frame : 15974652, Train reward : 39.0,
# Train Episode :9895, Total Frame : 15977660, Train reward : 19.0,
# Train Episode :9896, Total Frame : 15981992, Train reward : 77.0,
# Train Episode :9897, Total Frame : 15985212, Train reward : 40.0,
# Train Episode :9898, Total Frame : 15990768, Train reward : 72.0,
# Train Episode :9899, Total Frame : 15995768, Train reward : 57.0,
# ※Test※ 	 Frames: 6656 	 Score: 100.0
# Train Episode :9900, Total Frame : 15998308, Train reward : 47.0,
# Update Target
# Train Episode :9901, Total Frame : 16003156, Train reward : 55.0,
# Train Episode :9902, Total Frame : 16006608, Train reward : 27.0,
# Train Episode :9903, Total Frame : 16011660, Train reward : 51.0,
# Train Episode :9904, Total Frame : 16017304, Train reward : 63.0,
# Train Episode :9905, Total Frame : 16022976, Train reward : 88.0,
# Train Episode :9906, Total Frame : 16028120, Train reward : 59.0,
# Train Episode :9907, Total Frame : 16032940, Train reward : 73.0,
# Train Episode :9908, Total Frame : 16036360, Train reward : 24.0,
# Update Target
# Train Episode :9909, Total Frame : 16041376, Train reward : 48.0,
# ※Test※ 	 Frames: 5258 	 Score: 96.0
# Train Episode :9910, Total Frame : 16046632, Train reward : 60.0,
# Train Episode :9911, Total Frame : 16052076, Train reward : 70.0,
# Train Episode :9912, Total Frame : 16056404, Train reward : 45.0,
# Train Episode :9913, Total Frame : 16059932, Train reward : 25.0,
# Train Episode :9914, Total Frame : 16063828, Train reward : 44.0,
# Train Episode :9915, Total Frame : 16068288, Train reward : 67.0,
# Train Episode :9916, Total Frame : 16072624, Train reward : 37.0,
# Train Episode :9917, Total Frame : 16077684, Train reward : 45.0,
# Update Target
# Train Episode :9918, Total Frame : 16082324, Train reward : 60.0,
# Train Episode :9919, Total Frame : 16086768, Train reward : 54.0,
# ※Test※ 	 Frames: 4129 	 Score: 50.0
# Train Episode :9920, Total Frame : 16091876, Train reward : 52.0,
# Train Episode :9921, Total Frame : 16097828, Train reward : 77.0,
# Train Episode :9922, Total Frame : 16102816, Train reward : 60.0,
# Train Episode :9923, Total Frame : 16108992, Train reward : 84.0,
# Train Episode :9924, Total Frame : 16114568, Train reward : 73.0,
# Train Episode :9925, Total Frame : 16118440, Train reward : 39.0,
# Update Target
# Train Episode :9926, Total Frame : 16123140, Train reward : 56.0,
# Train Episode :9927, Total Frame : 16128628, Train reward : 64.0,
# Train Episode :9928, Total Frame : 16132116, Train reward : 34.0,
# Train Episode :9929, Total Frame : 16136896, Train reward : 71.0,
# ※Test※ 	 Frames: 5949 	 Score: 98.0
# Train Episode :9930, Total Frame : 16140812, Train reward : 47.0,
# Train Episode :9931, Total Frame : 16144948, Train reward : 191.0,
# Train Episode :9932, Total Frame : 16149192, Train reward : 69.0,
# Train Episode :9933, Total Frame : 16154660, Train reward : 69.0,
# Train Episode :9934, Total Frame : 16158840, Train reward : 49.0,
# Update Target
# Train Episode :9935, Total Frame : 16163124, Train reward : 42.0,
# Train Episode :9936, Total Frame : 16166864, Train reward : 59.0,
# Train Episode :9937, Total Frame : 16170264, Train reward : 40.0,
# Train Episode :9938, Total Frame : 16174656, Train reward : 70.0,
# Train Episode :9939, Total Frame : 16180864, Train reward : 85.0,
# ※Test※ 	 Frames: 6313 	 Score: 88.0
# Train Episode :9940, Total Frame : 16185640, Train reward : 56.0,
# Train Episode :9941, Total Frame : 16188744, Train reward : 36.0,
# Train Episode :9942, Total Frame : 16194200, Train reward : 57.0,
# Train Episode :9943, Total Frame : 16199300, Train reward : 68.0,
# Update Target
# Train Episode :9944, Total Frame : 16205640, Train reward : 94.0,
# Train Episode :9945, Total Frame : 16209324, Train reward : 41.0,
# Train Episode :9946, Total Frame : 16213724, Train reward : 31.0,
# Train Episode :9947, Total Frame : 16219228, Train reward : 83.0,
# Train Episode :9948, Total Frame : 16223904, Train reward : 51.0,
# Train Episode :9949, Total Frame : 16228376, Train reward : 56.0,
# ※Test※ 	 Frames: 5507 	 Score: 113.0
# Train Episode :9950, Total Frame : 16232344, Train reward : 43.0,
# Train Episode :9951, Total Frame : 16234888, Train reward : 18.0,
# Update Target
# Train Episode :9952, Total Frame : 16241316, Train reward : 74.0,
# Train Episode :9953, Total Frame : 16244916, Train reward : 51.0,
# Train Episode :9954, Total Frame : 16248424, Train reward : 53.0,
# Train Episode :9955, Total Frame : 16254080, Train reward : 68.0,
# Train Episode :9956, Total Frame : 16259156, Train reward : 59.0,
# Train Episode :9957, Total Frame : 16263724, Train reward : 53.0,
# Train Episode :9958, Total Frame : 16267864, Train reward : 38.0,
# Train Episode :9959, Total Frame : 16273520, Train reward : 59.0,
# ※Test※ 	 Frames: 6321 	 Score: 71.0
# Train Episode :9960, Total Frame : 16279320, Train reward : 80.0,
# Update Target
# Train Episode :9961, Total Frame : 16281872, Train reward : 33.0,
# Train Episode :9962, Total Frame : 16287944, Train reward : 84.0,
# Train Episode :9963, Total Frame : 16290132, Train reward : 27.0,
# Train Episode :9964, Total Frame : 16294564, Train reward : 41.0,
# Train Episode :9965, Total Frame : 16299296, Train reward : 293.0,
# Train Episode :9966, Total Frame : 16303596, Train reward : 43.0,
# Train Episode :9967, Total Frame : 16308448, Train reward : 71.0,
# Train Episode :9968, Total Frame : 16313704, Train reward : 55.0,
# Train Episode :9969, Total Frame : 16317652, Train reward : 35.0,
# ※Test※ 	 Frames: 3677 	 Score: 45.0
# Update Target
# Train Episode :9970, Total Frame : 16322520, Train reward : 57.0,
# Train Episode :9971, Total Frame : 16326100, Train reward : 34.0,
# Train Episode :9972, Total Frame : 16330968, Train reward : 51.0,
# Train Episode :9973, Total Frame : 16334364, Train reward : 28.0,
# Train Episode :9974, Total Frame : 16339700, Train reward : 73.0,
# Train Episode :9975, Total Frame : 16344524, Train reward : 89.0,
# Train Episode :9976, Total Frame : 16349344, Train reward : 80.0,
# Train Episode :9977, Total Frame : 16353264, Train reward : 31.0,
# Train Episode :9978, Total Frame : 16356208, Train reward : 21.0,
# Update Target
# Train Episode :9979, Total Frame : 16362252, Train reward : 74.0,
# ※Test※ 	 Frames: 6071 	 Score: 301.0
# Train Episode :9980, Total Frame : 16366484, Train reward : 42.0,
# Train Episode :9981, Total Frame : 16369840, Train reward : 31.0,
# Train Episode :9982, Total Frame : 16375292, Train reward : 71.0,
# Train Episode :9983, Total Frame : 16381356, Train reward : 91.0,
# Train Episode :9984, Total Frame : 16386120, Train reward : 62.0,
# Train Episode :9985, Total Frame : 16392268, Train reward : 79.0,
# Train Episode :9986, Total Frame : 16395040, Train reward : 20.0,
# Update Target
# Train Episode :9987, Total Frame : 16401584, Train reward : 100.0,
# Train Episode :9988, Total Frame : 16405376, Train reward : 36.0,
# Train Episode :9989, Total Frame : 16409280, Train reward : 50.0,
# ※Test※ 	 Frames: 6506 	 Score: 86.0
# Train Episode :9990, Total Frame : 16412772, Train reward : 37.0,
# Train Episode :9991, Total Frame : 16417744, Train reward : 64.0,
# Train Episode :9992, Total Frame : 16423488, Train reward : 86.0,
# Train Episode :9993, Total Frame : 16426848, Train reward : 36.0,
# Train Episode :9994, Total Frame : 16429028, Train reward : 15.0,
# Train Episode :9995, Total Frame : 16433980, Train reward : 47.0,
# Train Episode :9996, Total Frame : 16437552, Train reward : 40.0,
# Update Target
# Train Episode :9997, Total Frame : 16441552, Train reward : 40.0,
# Train Episode :9998, Total Frame : 16446812, Train reward : 47.0,
# Train Episode :9999, Total Frame : 16451828, Train reward : 103.0,
# ※Test※ 	 Frames: 3279 	 Score: 26.0
# Train Episode :10000, Total Frame : 16456056, Train reward : 39.0,
# Train Episode :10001, Total Frame : 16460964, Train reward : 93.0,
# Train Episode :10002, Total Frame : 16466808, Train reward : 65.0,
# Train Episode :10003, Total Frame : 16471340, Train reward : 45.0,
# Train Episode :10004, Total Frame : 16475984, Train reward : 59.0,
# Update Target
# Train Episode :10005, Total Frame : 16481936, Train reward : 73.0,
# Train Episode :10006, Total Frame : 16485840, Train reward : 51.0,
# Train Episode :10007, Total Frame : 16490824, Train reward : 51.0,
# Train Episode :10008, Total Frame : 16493836, Train reward : 34.0,
# Train Episode :10009, Total Frame : 16498376, Train reward : 80.0,
# ※Test※ 	 Frames: 6784 	 Score: 110.0
# Train Episode :10010, Total Frame : 16503316, Train reward : 47.0,
# Train Episode :10011, Total Frame : 16506156, Train reward : 24.0,
# Train Episode :10012, Total Frame : 16510832, Train reward : 67.0,
# Train Episode :10013, Total Frame : 16514788, Train reward : 45.0,
# Update Target
# Train Episode :10014, Total Frame : 16520452, Train reward : 62.0,
# Train Episode :10015, Total Frame : 16523992, Train reward : 56.0,
# Train Episode :10016, Total Frame : 16529848, Train reward : 76.0,
# Train Episode :10017, Total Frame : 16535712, Train reward : 75.0,
# Train Episode :10018, Total Frame : 16541316, Train reward : 79.0,
# Train Episode :10019, Total Frame : 16548200, Train reward : 124.0,
# ※Test※ 	 Frames: 5756 	 Score: 81.0
# Train Episode :10020, Total Frame : 16551036, Train reward : 17.0,
# Train Episode :10021, Total Frame : 16556212, Train reward : 78.0,
# Update Target
# Train Episode :10022, Total Frame : 16562092, Train reward : 65.0,
# Train Episode :10023, Total Frame : 16565648, Train reward : 37.0,
# Train Episode :10024, Total Frame : 16570628, Train reward : 60.0,
# Train Episode :10025, Total Frame : 16574620, Train reward : 34.0,
# Train Episode :10026, Total Frame : 16580304, Train reward : 73.0,
# Train Episode :10027, Total Frame : 16585164, Train reward : 60.0,
# Train Episode :10028, Total Frame : 16590596, Train reward : 105.0,
# Train Episode :10029, Total Frame : 16596204, Train reward : 72.0,
# ※Test※ 	 Frames: 5446 	 Score: 63.0
# Update Target
# Train Episode :10030, Total Frame : 16603304, Train reward : 90.0,
# Train Episode :10031, Total Frame : 16608384, Train reward : 77.0,
# Train Episode :10032, Total Frame : 16613648, Train reward : 71.0,
# Train Episode :10033, Total Frame : 16617324, Train reward : 30.0,
# Train Episode :10034, Total Frame : 16622904, Train reward : 213.0,
# Train Episode :10035, Total Frame : 16628888, Train reward : 84.0,
# Train Episode :10036, Total Frame : 16634488, Train reward : 74.0,
# Update Target
# Train Episode :10037, Total Frame : 16641000, Train reward : 126.0,
# Train Episode :10038, Total Frame : 16645620, Train reward : 48.0,
# Train Episode :10039, Total Frame : 16649424, Train reward : 42.0,
# ※Test※ 	 Frames: 4236 	 Score: 51.0
# Train Episode :10040, Total Frame : 16655020, Train reward : 61.0,
# Train Episode :10041, Total Frame : 16659704, Train reward : 42.0,
# Train Episode :10042, Total Frame : 16663260, Train reward : 55.0,
# Train Episode :10043, Total Frame : 16667280, Train reward : 51.0,
# Train Episode :10044, Total Frame : 16672536, Train reward : 75.0,
# Train Episode :10045, Total Frame : 16678384, Train reward : 80.0,
# Update Target
# Train Episode :10046, Total Frame : 16683264, Train reward : 56.0,
# Train Episode :10047, Total Frame : 16688024, Train reward : 103.0,
# Train Episode :10048, Total Frame : 16691420, Train reward : 39.0,
# Train Episode :10049, Total Frame : 16695284, Train reward : 40.0,
# ※Test※ 	 Frames: 5122 	 Score: 64.0
# Train Episode :10050, Total Frame : 16700484, Train reward : 57.0,
# Train Episode :10051, Total Frame : 16705664, Train reward : 49.0,
# Train Episode :10052, Total Frame : 16709352, Train reward : 37.0,
# Train Episode :10053, Total Frame : 16711900, Train reward : 15.0,
# Train Episode :10054, Total Frame : 16716712, Train reward : 55.0,
# Update Target
# Train Episode :10055, Total Frame : 16720896, Train reward : 42.0,
# Train Episode :10056, Total Frame : 16725504, Train reward : 51.0,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-d7039d1ee483> in <module>
#       1 max_frame = 50000000
# ----> 2 fitter.train(max_frame)
#
# <ipython-input-13-6dba58f4d78c> in train(self, max_total_frame)
#     105                 # training when enough replay-memory, every k-frames
#     106                 if len(self.replay_memory) > self.min_replay:
# --> 107                     self.train_batch(self.batch_size)
#     108                     self.total_frame += self.k
#     109
#
# <ipython-input-13-6dba58f4d78c> in train_batch(self, batch_size)
#     145             next_actions = torch.argmax(self.behavior_net(S_next), dim=1) # choose argmax behavior actions at S_next
#     146
# --> 147             q_targets_next = self.target_net(S_next) # cal Q-values of every possible actions next state (targetDQN)
#     148             q_target_next = self.select_indices(q_targets_next, next_actions) # select Q-value for next behavior actions
#     149             q_target = R + self.gamma*q_target_next*(1-D)
#
# ~/anaconda3/envs/tf2/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-9-1bffaebcc708> in forward(self, frames)
#      22
#      23     def forward(self, frames):
# ---> 24         frames = self.to_tensor(frames)
#      25         conved = self.conv(frames)
#      26         conved = conved.view(conved.size(0), -1)
#
# <ipython-input-9-1bffaebcc708> in to_tensor(self, img)
#      15
#      16     def to_tensor(self, img):
# ---> 17         img = torch.tensor(img, dtype=torch.float32, device=self.device).cuda(non_blocking=True) # to tensor
#      18         img /= 255                                   # normalize into 0-1
#      19         while img.dim() < 4 :                        # 4-dim
#
# KeyboardInterrupt:

# %%
fitter.total_frame
# Out:
# 16730460

# %%
plt.plot(fitter.train_reward_ls)

# %%
torch.save(fitter.behavior_net.state_dict(), 'BreakoutDoubleDQN_state_dict')

# %%
plt.plot(fitter.test_reward_ls)

# %%
from collections import Counter

ls = []
S_ls = []
for _ in range(100):
    S = fitter.replay_memory.sample(1)[0][0]
    print(fitter.behavior_net(S).data)
    #print(fitter.behavior_net(S).argmax().item())
    ls.append(fitter.behavior_net(S).argmax().item())
    #plt.imshow(S[3])
plt.imshow(S[0])
Counter(ls)
# Out:
# tensor([[0.8572, 0.9168, 0.8955, 0.8678]], device='cuda:0')
# tensor([[0.7344, 0.7749, 0.7960, 0.7344]], device='cuda:0')
# tensor([[0.9327, 0.9411, 0.8770, 0.9452]], device='cuda:0')
# tensor([[0.5917, 0.5709, 0.6286, 0.5887]], device='cuda:0')
# tensor([[0.3456, 0.3642, 0.3474, 0.3557]], device='cuda:0')
# tensor([[0.1723, 0.1992, 0.2139, 0.1884]], device='cuda:0')
# tensor([[1.1974, 1.2020, 1.2044, 1.2440]], device='cuda:0')
# tensor([[0.2510, 0.2695, 0.2752, 0.2786]], device='cuda:0')
# tensor([[0.2836, 0.3277, 0.3246, 0.3347]], device='cuda:0')
# tensor([[0.4145, 0.4218, 0.4354, 0.4101]], device='cuda:0')
# tensor([[0.4582, 0.4521, 0.4648, 0.4324]], device='cuda:0')
# tensor([[0.3075, 0.3675, 0.3347, 0.3342]], device='cuda:0')
# tensor([[0.0904, 0.1190, 0.1116, 0.1297]], device='cuda:0')
# tensor([[0.5534, 0.5607, 0.5877, 0.5788]], device='cuda:0')
# tensor([[0.2532, 0.3144, 0.2847, 0.2793]], device='cuda:0')
# tensor([[0.5022, 0.5255, 0.4985, 0.5610]], device='cuda:0')
# tensor([[0.8848, 0.9018, 0.8901, 0.8697]], device='cuda:0')
# tensor([[0.3477, 0.3641, 0.3637, 0.3525]], device='cuda:0')
# tensor([[0.8148, 0.8409, 0.8372, 0.8161]], device='cuda:0')
# tensor([[0.1742, 0.2002, 0.1873, 0.2026]], device='cuda:0')
# tensor([[0.4952, 0.5021, 0.5036, 0.4879]], device='cuda:0')
# tensor([[1.0792, 1.0709, 1.0755, 1.0513]], device='cuda:0')
# tensor([[0.2889, 0.3007, 0.3023, 0.3031]], device='cuda:0')
# tensor([[0.4049, 0.4075, 0.4186, 0.3881]], device='cuda:0')
# tensor([[0.5553, 0.5895, 0.5938, 0.5415]], device='cuda:0')
# tensor([[1.0846, 1.0473, 1.1452, 1.0755]], device='cuda:0')
# tensor([[0.4493, 0.4578, 0.4593, 0.4711]], device='cuda:0')
# tensor([[0.9548, 1.0344, 1.0248, 0.9889]], device='cuda:0')
# tensor([[1.8402, 1.8377, 1.8513, 1.8303]], device='cuda:0')
# tensor([[1.5757, 1.6114, 1.5799, 1.5660]], device='cuda:0')
# tensor([[0.2726, 0.3094, 0.3236, 0.3073]], device='cuda:0')
# tensor([[0.2075, 0.2392, 0.2307, 0.2379]], device='cuda:0')
# tensor([[0.3286, 0.3561, 0.3685, 0.3472]], device='cuda:0')
# tensor([[0.8839, 0.8980, 0.8968, 0.8837]], device='cuda:0')
# tensor([[0.3219, 0.3163, 0.3200, 0.3295]], device='cuda:0')
# tensor([[1.0276, 1.0531, 1.0686, 1.0352]], device='cuda:0')
# tensor([[0.6780, 0.6932, 0.7141, 0.6656]], device='cuda:0')
# tensor([[0.2241, 0.2571, 0.2453, 0.2552]], device='cuda:0')
# tensor([[1.4902, 1.4511, 1.4477, 1.3982]], device='cuda:0')
# tensor([[0.2563, 0.2846, 0.2657, 0.2821]], device='cuda:0')
# tensor([[0.4613, 0.4899, 0.4880, 0.5218]], device='cuda:0')
# tensor([[1.2997, 1.3183, 1.3186, 1.2556]], device='cuda:0')
# tensor([[0.1655, 0.2032, 0.2037, 0.2118]], device='cuda:0')
# tensor([[0.7630, 0.7996, 0.8016, 0.7904]], device='cuda:0')
# tensor([[0.5746, 0.6016, 0.6228, 0.6221]], device='cuda:0')
# tensor([[0.4893, 0.5092, 0.4798, 0.5225]], device='cuda:0')
# tensor([[1.3372, 1.3415, 1.3642, 1.3202]], device='cuda:0')
# tensor([[0.4489, 0.4862, 0.4978, 0.5389]], device='cuda:0')
# tensor([[1.0246, 1.0317, 1.0273, 1.0257]], device='cuda:0')
# tensor([[0.4326, 0.4435, 0.4439, 0.4519]], device='cuda:0')
# tensor([[0.1742, 0.2002, 0.1873, 0.2026]], device='cuda:0')
# tensor([[0.2750, 0.3150, 0.2797, 0.2951]], device='cuda:0')
# tensor([[0.2310, 0.2443, 0.2631, 0.2521]], device='cuda:0')
# tensor([[0.9698, 0.9837, 1.0063, 0.9975]], device='cuda:0')
# tensor([[0.2806, 0.2972, 0.3309, 0.2834]], device='cuda:0')
# tensor([[0.6136, 0.6675, 0.6490, 0.6557]], device='cuda:0')
# tensor([[0.2822, 0.3396, 0.3546, 0.3153]], device='cuda:0')
# tensor([[0.3922, 0.3826, 0.4144, 0.3715]], device='cuda:0')
# tensor([[0.7597, 0.7729, 0.7739, 0.7665]], device='cuda:0')
# tensor([[0.1070, 0.1362, 0.1528, 0.1230]], device='cuda:0')
# tensor([[1.3448, 1.4363, 1.4164, 1.3963]], device='cuda:0')
# tensor([[0.8475, 0.8600, 0.8617, 0.8473]], device='cuda:0')
# tensor([[0.3319, 0.3407, 0.3553, 0.3410]], device='cuda:0')
# tensor([[1.0080, 0.9737, 1.0005, 0.9567]], device='cuda:0')
# tensor([[1.5784, 1.5721, 1.5622, 1.5195]], device='cuda:0')
# tensor([[1.6206, 1.7307, 1.6446, 1.6409]], device='cuda:0')
# tensor([[0.6860, 0.7121, 0.6993, 0.6842]], device='cuda:0')
# tensor([[0.2230, 0.2504, 0.2330, 0.2413]], device='cuda:0')
# tensor([[0.4591, 0.4391, 0.5293, 0.4544]], device='cuda:0')
# tensor([[0.2633, 0.3116, 0.2987, 0.2957]], device='cuda:0')
# tensor([[1.7230, 1.6871, 1.7340, 1.6484]], device='cuda:0')
# tensor([[0.2241, 0.2571, 0.2453, 0.2552]], device='cuda:0')
# tensor([[1.5276, 1.5200, 1.5304, 1.4655]], device='cuda:0')
# tensor([[0.2295, 0.2682, 0.2490, 0.2618]], device='cuda:0')
# tensor([[1.0998, 1.0627, 1.0499, 1.0376]], device='cuda:0')
# tensor([[1.3523, 1.3700, 1.3703, 1.3145]], device='cuda:0')
# tensor([[0.2255, 0.2418, 0.2309, 0.2437]], device='cuda:0')
# tensor([[1.1406, 1.1366, 1.1808, 1.1147]], device='cuda:0')
# tensor([[1.6542, 1.7537, 1.6677, 1.6786]], device='cuda:0')
# tensor([[0.9313, 0.9182, 0.9474, 0.9248]], device='cuda:0')
# tensor([[0.2946, 0.2916, 0.3055, 0.3292]], device='cuda:0')
# tensor([[1.4851, 1.4753, 1.5356, 1.4708]], device='cuda:0')
# tensor([[0.3512, 0.3612, 0.3643, 0.3633]], device='cuda:0')
# tensor([[0.8327, 0.8279, 0.8603, 0.8220]], device='cuda:0')
# tensor([[0.5156, 0.5094, 0.5266, 0.4959]], device='cuda:0')
# tensor([[0.1449, 0.1554, 0.1695, 0.1678]], device='cuda:0')
# tensor([[0.3846, 0.3911, 0.3793, 0.4062]], device='cuda:0')
# tensor([[0.8941, 0.8937, 0.9118, 0.8959]], device='cuda:0')
# tensor([[0.4032, 0.4519, 0.4341, 0.4276]], device='cuda:0')
# tensor([[1.0749, 1.1528, 1.0898, 1.0799]], device='cuda:0')
# tensor([[1.3439, 1.3595, 1.3519, 1.3351]], device='cuda:0')
# tensor([[0.4972, 0.4838, 0.5072, 0.4994]], device='cuda:0')
# tensor([[1.5169, 1.4903, 1.5070, 1.4847]], device='cuda:0')
# tensor([[1.6316, 1.6302, 1.6383, 1.5998]], device='cuda:0')
# tensor([[0.6419, 0.6977, 0.6925, 0.6690]], device='cuda:0')
# tensor([[1.4730, 1.4820, 1.4549, 1.4639]], device='cuda:0')
# tensor([[0.2965, 0.3061, 0.3017, 0.3217]], device='cuda:0')
# tensor([[1.4056, 1.3545, 1.3740, 1.3492]], device='cuda:0')
# tensor([[1.4558, 1.5270, 1.5043, 1.4874]], device='cuda:0')
# tensor([[0.4497, 0.4733, 0.4692, 0.4466]], device='cuda:0')
# Counter({1: 31, 2: 42, 3: 20, 0: 7})

# %%
def play_game(fitter):
    fitter.reset_episode()
    img = plt.imshow(fitter.env.render(mode='rgb_array')) # only call this once
    
    done=False
    while not done:
        img.set_data(fitter.env.render(mode='rgb_array')) # just update the data
        display.display(plt.gcf())
        display.clear_output(wait=True)
        
        fitter.run_k_frames(is_training=False)
    
    fitter.env.close()
    return

# %%
plt.plot(fitter.train_reward_ls)

# %%
plt.plot(fitter.test_reward_ls)
