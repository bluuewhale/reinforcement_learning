# %%
import torch
import torch.nn as nn

# Import the gym module
import gym
import numpy as np
import time 

from matplotlib import pyplot as plt

import random

import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

# %%
class NoopResetEnv(gym.Wrapper):
    def __init__(self, env, noop_max=30):
        '''첫 번째 트릭 No-Operation. 초기화 후 일정 단계에 이를때까지 아무 행동도 하지않고
        게임 초기 상태를 다양하게 하여 특정 시작 상태만 학습하는 것을 방지한다'''

        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def reset(self, **kwargs):
        """ Do no-op action for a number of steps in [1, noop_max]."""
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = self.unwrapped.np_random.randint(
                1, self.noop_max + 1)  # pylint: disable=E1101
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, done, _ = self.env.step(self.noop_action)
            if done:
                obs = self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)

# %%
# Create a breakout environment
env = gym.make('BreakoutNoFrameskip-v4')
env = NoopResetEnv(env, noop_max=30)

# %%
def preprocess(img):
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img = cv2.resize(img, (84, 84), interpolation=cv2.INTER_AREA)
    return np.expand_dims(img, 0) # (1, 80, 80)

# %%
env.reset()
img = plt.imshow(env.render(mode='rgb_array')) # only call this once
for _ in range(30):
    img.set_data(env.render(mode='rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    action = env.action_space.sample()
    env.step(action)

# %%
env.reset()
for _ in range(30):
    s, _, _, _ = env.step(env.action_space.sample())

plt.imshow(preprocess(s)[0])

# %%
from collections import deque
import random 

class ReplayMemory(object):
    def __init__(self, capacity):
        self.deque = deque(maxlen=capacity)

    def append(self, state, action, reward, next_state, done):
        self.deque.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        state, action, reward, next_state, done = zip(*random.sample(self.deque, batch_size))
        return np.concatenate(state), action, reward, np.concatenate(next_state), done
    
    def __len__(self):
        return len(self.deque)

# %%
class FrameHistory(object):
    # consecutive frame을 4개씩 병합하여 새로운 x를 하나씩 만드는 클래스
    # 만들어진 x는 4개씩 concat하고 s를 만들어서 DQN의 input으로 들어감
    def __init__(self, env, k=4):
        self.state_deque = deque(maxlen=k) # [x1, x2, x3, x4]
        self.frame_history_deque = deque(maxlen=k) #[s1, s2, s3, s4]
        self.k = k
        
        # 최초에는 초기 화면(env.reset)으로 채워둠
        self.env = env
        self.initial_state = self.preprocess(self.env.reset())
        self.reset()
        
    def preprocess(self, img):
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        img = cv2.resize(img, (84, 84), interpolation=cv2.INTER_AREA)
        return np.expand_dims(img, 0) # (1, 80, 80)
    
    def append_frame(self, s):
        # if full, aggregate and clear old frames, append new frame to history queue
        self.frame_history_deque.append(self.preprocess(s))
        
        if len(self) == self.k:
            self.state_deque.append(self.aggregate_frame())
        return
        
    def aggregate_frame(self):
        if len(self) < self.k:
            raise ValueError('not enough frames in history, expected %s, but got %s'%(self.k, len(self)))
        
        # element-wise maximum to aggregate
        frame_history = [self.frame_history_deque.popleft() for _ in range(self.k)]
        return np.maximum.reduce(frame_history[-2:]) #마지막 2 프레임 사용 
    
    def get_state(self):
        S = np.array([self.state_deque[i] for i in range(self.k)]) # S = [x1, x2, x3, x4], (4, 1, 80, 80)
        S = np.swapaxes(S, 0, 1) # (1, 4, 80, 80)
        return S
    
    def reset(self):
        self.frame_history_deque = deque(maxlen=k)
        self.state_deque = deque(maxlen=k)
        
        for _ in range(self.k):
            self.state_deque.append(self.initial_state)
    
    def __len__(self):
        return len(self.frame_history_deque)

# %%
class DDQN(nn.Module):
    # Dueling DQN
    def __init__(self, in_dim, n_action):
        super(DDQN, self).__init__()
        self.device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
        
        self.conv = nn.Sequential(
            nn.Conv2d(in_dim, 32, (8, 8), stride=4), nn.ReLU(), # conv 1
            nn.Conv2d(32, 64, (4, 4), stride=2), nn.ReLU(), # conv 2
            nn.Conv2d(64, 64, (3, 3), stride=1), nn.ReLU() # conv 3
        )
        # V(s) : value-stream
        self.value_stream = nn.Sequential(
            nn.Linear(64*7*7, 512), nn.ReLU(), # hidden layer
            nn.Linear(512, 1)
        )
        
        # A(s,a) : action-stream
        self.action_stream = nn.Sequential(
            nn.Linear(64*7*7, 512), nn.ReLU(),
            nn.Linear(512, n_action)
        )
        
    def prep_for_input(self, img):
        img = torch.tensor(img, dtype=torch.float32, device=self.device).cuda(non_blocking=True) # to tensor
        img /= 255                                   # normalize into 0-1
        while img.dim() < 4 :                        # 4-dim
            img = img.unsqueeze(0)
        return img
        
    def forward(self, frames):
        frames = self.prep_for_input(frames) 
        conved = self.conv(frames)
        conved = conved.view(conved.size(0), -1)
        
        # key of Dueling DQN : Q(s,a_i) = V(S) + A(s,a_i) - mean(A)
        value = self.value_stream(conved) # V(s), dim=(batch_size, 1)
        action = self.action_stream(conved) # A(s,a), dim=(batch_size, n_action)
        
        output = value + (action - torch.mean(action, dim=1, keepdim=True)) # V(s) + (A(s,a_i) - mean(A)), dim=(batch_size, n_action)
        return output

# %%
import torch.nn.init as init

def weight_init(m):
    '''
    Usage:
        model = Model()
        model.apply(weight_init)
    '''
    if isinstance(m, nn.Conv2d):
        init.xavier_normal_(m.weight.data)
        if m.bias is not None:
            init.normal_(m.bias.data)

    elif isinstance(m, nn.Linear):
        init.xavier_normal_(m.weight.data)
        init.normal_(m.bias.data)
    
    return

# %%
#############
k = 4 ## number of skipped frame
#############

behavior_net = DDQN(in_dim=k, n_action=4)
target_net = DDQN(in_dim=k, n_action=4)

behavior_net.to(behavior_net.device) # model to cuda
target_net.to(target_net.device)     # model to cuda

behavior_net.apply(weight_init)
target_net.apply(weight_init)
# Out:
# DDQN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (value_stream): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=1, bias=True)
#   )
#   (action_stream): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=4, bias=True)
#   )
# )

# %%
class Fitter():
    def __init__(self, env, behavior_net, target_net, k=4, train_method='DQN'):
        self.env = env
        self.train_method = train_method
        self.device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
        self.save_path = ('BreakoutDuelingDQN_state_dict')

        # networks
        self.behavior_net = behavior_net
        self.target_net = target_net
        self.behavior_net.to(self.behavior_net.device) # model to cuda
        self.target_net.to(self.target_net.device)     # model to cuda
        
        # train parameters
        self.gamma = 0.99 #as written in paper
        self.criterion = nn.SmoothL1Loss() # huber loss (error-clipping)
        self.optim = torch.optim.RMSprop(self.behavior_net.parameters(), lr=0.00025, alpha=0.95, eps=0.01) #as written in paper in Rainbow
        self.k = k
        
        # train details
        self.total_frame = 0
        self.total_episode = 0
        
        self.test_e = 0.05
        self.batch_size = 32
        self.max_replay = 250000 # not as written in paper
        self.min_replay = 50000 # not as written in the paper
        self.replay_memory = ReplayMemory(self.max_replay)
        self.frame_history = FrameHistory(env=self.env, k=self.k)
        
        self.train_reward_ls = []
        self.test_reward_ls = []
    
    # train-epsilon
    @property
    def train_e(self):
        return np.max([1 - 9.0*1e-07*self.total_frame, 0.1])
    
    
    def reset_episode(self):
        # game(episode) begins
        self.env.reset()  
        self.frame_history.reset() #frame history reset
        self.current_episode_frame = 0         # each episode의 frame 수 
        self.current_episode_reward = 0        # each episode의 reward 합
        self.current_life = 5
    
    def choose_action(self, S, e):
        # at the beginning of an episode, do something
        if self.current_episode_frame == 0:
            a = 1
        else:
            # Choose an action by e-greedy
            if np.random.rand(1) < e :
                a = self.env.action_space.sample()
            else:
                q_behavior = self.behavior_net(S)
                a = torch.argmax(q_behavior).item()
        return a
    
    
    def run_k_frames(self, e):
        # choose action!
        S = self.frame_history.get_state()
        a = self.choose_action(S, e)
        r_sum = 0
        
        # repeat the action k-times
        for _ in range(self.k):
            s_next, r, done, info = self.env.step(a)
            self.frame_history.append_frame(s_next)
            r_sum += self.clip_reward(r) # store clipped reward for future training replay(experience)
            
            # accumulate history
            self.current_episode_frame += 1
            self.current_episode_reward += r
            
            # if episode(game) ends, return done(True)
            if done: 
                return done
            
        # concat last k-frames into a next state S_next
        S_next = self.frame_history.get_state()
        
        # Terminal when lose life
        if info['ale.lives'] < self.current_life:
            self.current_life = info['ale.lives']
            terminal = True
            self.replay_memory.append(S, a, r_sum, S_next, terminal) # save replay(experience)
        
        else:
            self.replay_memory.append(S, a, r_sum, S_next, done) # save replay(experience)
            
        return done

    
    def train(self, max_total_frame):
        while self.total_frame < max_total_frame :
            # episode starts!
            self.reset_episode()
            
            done = False
            while not done:
                done = self.run_k_frames(e=self.train_e)
                
                # training when enough replay-memory, every k-frames
                if len(self.replay_memory) > self.min_replay:
                    self.train_batch(self.batch_size)   
                    self.total_frame += self.k
                    
                    # update target_net every 10,000 updates
                    if self.total_frame%(self.k*10000)== 0 :
                        self.update_target()
                        self.save()
                
            # single-episode(game) is now done
            # if not enough memory, save more
            if len(self.replay_memory) < self.min_replay:
                print('Not enough replay yet, expected more than %s, but %s instead'%(self.min_replay, len(self.replay_memory)))
            
            # if enough memory, print train result
            else:
                print('Train Episode :%s, Total Frame : %s, Train reward : %s,'%(self.total_episode, self.total_frame, self.current_episode_reward))
                self.total_episode += 1
                self.train_reward_ls.append(self.current_episode_reward)
            
                # testing, every 10 episodes when enough replay
                if self.total_episode%10 == 0:
                    self.test()           

    def train_batch(self, batch_size):
        # get mini-batch from replay-memory
        S, A, R, S_next, D = self.replay_memory.sample(batch_size)
        A = self.to_tensor(A, dtype=torch.long)
        R = self.to_tensor(R, dtype=torch.float32)
        D = self.to_tensor(D, dtype=torch.float32)
        
        q_behaviors = self.behavior_net(S)                # Q-values for every possible actions
        q_behavior = self.select_indices(q_behaviors, A) # select Q-value for given actions
        
        if self.train_method=='DQN':
            q_targets_next = self.target_net(S_next)   # Q-values of every possible actions next state (targetDQN)
            q_target_next = q_targets_next.max(1)[0]   # max Q-values of next state
            q_target = R + self.gamma*q_target_next*(1-D) 
        
        elif self.train_method=='DoubleDQN':
            next_actions = torch.argmax(self.behavior_net(S_next), dim=1) # choose argmax behavior actions at S_next
            
            q_targets_next = self.target_net(S_next) # cal Q-values of every possible actions next state (targetDQN)
            q_target_next = self.select_indices(q_targets_next, next_actions) # select Q-value for next behavior actions
            q_target = R + self.gamma*q_target_next*(1-D)
        
        # update weights
        self.optim.zero_grad()
        loss = self.criterion(q_target, q_behavior)
        loss.backward()
        self.optim.step()
        return
        
    def to_tensor(self, x, dtype=torch.float):
        return torch.tensor(x, dtype=dtype, device=self.device)
    
    def select_indices(self, tensor, indices, dim=1):
        if type(indices) != torch.Tensor:
            indices = self.to_tensor(indices, dtype=torch.long)
        if indices.dim() < 2 :
            indices = indices.unsqueeze(1)
        return tensor.gather(dim, indices).squeeze(1)
    
    def clip_reward(self, r):
        return np.sign(r)
    
    
    def update_target(self):
        print('Update Target')
        self.target_net.load_state_dict(self.behavior_net.state_dict())
        return 
    
    def test(self):
        self.reset_episode()
        done=False
        while not done:
            done = self.run_k_frames(e=fitter.test_e) # e-greedy
                
        self.test_reward_ls.append(self.current_episode_reward)
        print('※Test※ \t Frames: %s \t Score: %s'%(self.current_episode_frame, self.current_episode_reward))
        return
     
    def save(self):
        torch.save(self.behavior_net.state_dict(), self.save_path)

# %%
fitter = Fitter(env, behavior_net, target_net, k=k, train_method='DoubleDQN')

# %%
max_frame = 50000000
fitter.train(max_frame)
# Out:
# Train Episode :16767, Total Frame : 19926844, Train reward : 6.0,
# Train Episode :16768, Total Frame : 19928900, Train reward : 13.0,
# Train Episode :16769, Total Frame : 19933096, Train reward : 47.0,
# ※Test※ 	 Frames: 5133 	 Score: 345.0
# Train Episode :16770, Total Frame : 19935980, Train reward : 21.0,
# Train Episode :16771, Total Frame : 19938368, Train reward : 25.0,
# Train Episode :16772, Total Frame : 19940816, Train reward : 15.0,
# Train Episode :16773, Total Frame : 19944480, Train reward : 36.0,
# Train Episode :16774, Total Frame : 19948940, Train reward : 41.0,
# Train Episode :16775, Total Frame : 19952080, Train reward : 19.0,
# Train Episode :16776, Total Frame : 19954328, Train reward : 20.0,
# Train Episode :16777, Total Frame : 19957820, Train reward : 32.0,
# Update Target
# Train Episode :16778, Total Frame : 19962292, Train reward : 43.0,
# Train Episode :16779, Total Frame : 19965616, Train reward : 19.0,
# ※Test※ 	 Frames: 4181 	 Score: 55.0
# Train Episode :16780, Total Frame : 19967820, Train reward : 43.0,
# Train Episode :16781, Total Frame : 19972596, Train reward : 41.0,
# Train Episode :16782, Total Frame : 19975104, Train reward : 29.0,
# Train Episode :16783, Total Frame : 19980264, Train reward : 58.0,
# Train Episode :16784, Total Frame : 19982600, Train reward : 13.0,
# Train Episode :16785, Total Frame : 19986120, Train reward : 33.0,
# Train Episode :16786, Total Frame : 19989512, Train reward : 32.0,
# Train Episode :16787, Total Frame : 19992612, Train reward : 21.0,
# Train Episode :16788, Total Frame : 19995416, Train reward : 15.0,
# Train Episode :16789, Total Frame : 19998444, Train reward : 21.0,
# ※Test※ 	 Frames: 2346 	 Score: 14.0
# Update Target
# Train Episode :16790, Total Frame : 20001372, Train reward : 29.0,
# Train Episode :16791, Total Frame : 20003472, Train reward : 12.0,
# Train Episode :16792, Total Frame : 20008288, Train reward : 49.0,
# Train Episode :16793, Total Frame : 20011368, Train reward : 21.0,
# Train Episode :16794, Total Frame : 20015868, Train reward : 42.0,
# Train Episode :16795, Total Frame : 20019896, Train reward : 33.0,
# Train Episode :16796, Total Frame : 20022536, Train reward : 16.0,
# Train Episode :16797, Total Frame : 20026844, Train reward : 41.0,
# Train Episode :16798, Total Frame : 20030852, Train reward : 31.0,
# Train Episode :16799, Total Frame : 20035280, Train reward : 251.0,
# ※Test※ 	 Frames: 1871 	 Score: 37.0
# Train Episode :16800, Total Frame : 20037312, Train reward : 11.0,
# Train Episode :16801, Total Frame : 20039920, Train reward : 22.0,
# Update Target
# Train Episode :16802, Total Frame : 20042884, Train reward : 40.0,
# Train Episode :16803, Total Frame : 20045660, Train reward : 20.0,
# Train Episode :16804, Total Frame : 20049680, Train reward : 40.0,
# Train Episode :16805, Total Frame : 20053144, Train reward : 32.0,
# Train Episode :16806, Total Frame : 20055384, Train reward : 19.0,
# Train Episode :16807, Total Frame : 20057036, Train reward : 21.0,
# Train Episode :16808, Total Frame : 20061168, Train reward : 37.0,
# Train Episode :16809, Total Frame : 20064016, Train reward : 15.0,
# ※Test※ 	 Frames: 3545 	 Score: 27.0
# Train Episode :16810, Total Frame : 20066556, Train reward : 26.0,
# Train Episode :16811, Total Frame : 20070016, Train reward : 34.0,
# Train Episode :16812, Total Frame : 20074204, Train reward : 42.0,
# Train Episode :16813, Total Frame : 20076856, Train reward : 14.0,
# Train Episode :16814, Total Frame : 20079568, Train reward : 22.0,
# Update Target
# Train Episode :16815, Total Frame : 20083264, Train reward : 33.0,
# Train Episode :16816, Total Frame : 20087024, Train reward : 40.0,
# Train Episode :16817, Total Frame : 20090720, Train reward : 37.0,
# Train Episode :16818, Total Frame : 20093088, Train reward : 37.0,
# Train Episode :16819, Total Frame : 20095252, Train reward : 15.0,
# ※Test※ 	 Frames: 3608 	 Score: 28.0
# Train Episode :16820, Total Frame : 20099212, Train reward : 29.0,
# Train Episode :16821, Total Frame : 20101484, Train reward : 17.0,
# Train Episode :16822, Total Frame : 20104100, Train reward : 17.0,
# Train Episode :16823, Total Frame : 20107696, Train reward : 32.0,
# Train Episode :16824, Total Frame : 20109464, Train reward : 14.0,
# Train Episode :16825, Total Frame : 20112640, Train reward : 23.0,
# Train Episode :16826, Total Frame : 20115220, Train reward : 20.0,
# Train Episode :16827, Total Frame : 20118936, Train reward : 35.0,
# Update Target
# Train Episode :16828, Total Frame : 20122628, Train reward : 33.0,
# Train Episode :16829, Total Frame : 20125340, Train reward : 20.0,
# ※Test※ 	 Frames: 3556 	 Score: 43.0
# Train Episode :16830, Total Frame : 20128676, Train reward : 24.0,
# Train Episode :16831, Total Frame : 20131160, Train reward : 16.0,
# Train Episode :16832, Total Frame : 20134592, Train reward : 35.0,
# Train Episode :16833, Total Frame : 20136648, Train reward : 15.0,
# Train Episode :16834, Total Frame : 20139920, Train reward : 23.0,
# Train Episode :16835, Total Frame : 20142216, Train reward : 15.0,
# Train Episode :16836, Total Frame : 20144704, Train reward : 28.0,
# Train Episode :16837, Total Frame : 20147788, Train reward : 31.0,
# Train Episode :16838, Total Frame : 20150444, Train reward : 57.0,
# Train Episode :16839, Total Frame : 20153080, Train reward : 17.0,
# ※Test※ 	 Frames: 4907 	 Score: 47.0
# Train Episode :16840, Total Frame : 20155620, Train reward : 22.0,
# Train Episode :16841, Total Frame : 20157776, Train reward : 37.0,
# Update Target
# Train Episode :16842, Total Frame : 20161528, Train reward : 36.0,
# Train Episode :16843, Total Frame : 20164648, Train reward : 29.0,
# Train Episode :16844, Total Frame : 20167636, Train reward : 18.0,
# Train Episode :16845, Total Frame : 20172016, Train reward : 41.0,
# Train Episode :16846, Total Frame : 20175240, Train reward : 29.0,
# Train Episode :16847, Total Frame : 20180260, Train reward : 50.0,
# Train Episode :16848, Total Frame : 20182984, Train reward : 24.0,
# Train Episode :16849, Total Frame : 20185368, Train reward : 14.0,
# ※Test※ 	 Frames: 4604 	 Score: 99.0
# Train Episode :16850, Total Frame : 20189252, Train reward : 48.0,
# Train Episode :16851, Total Frame : 20191132, Train reward : 12.0,
# Train Episode :16852, Total Frame : 20195724, Train reward : 36.0,
# Train Episode :16853, Total Frame : 20198136, Train reward : 16.0,
# Update Target
# Train Episode :16854, Total Frame : 20201080, Train reward : 18.0,
# Train Episode :16855, Total Frame : 20204460, Train reward : 24.0,
# Train Episode :16856, Total Frame : 20207556, Train reward : 23.0,
# Train Episode :16857, Total Frame : 20210940, Train reward : 31.0,
# Train Episode :16858, Total Frame : 20213904, Train reward : 26.0,
# Train Episode :16859, Total Frame : 20218092, Train reward : 27.0,
# ※Test※ 	 Frames: 2090 	 Score: 18.0
# Train Episode :16860, Total Frame : 20220828, Train reward : 20.0,
# Train Episode :16861, Total Frame : 20223608, Train reward : 39.0,
# Train Episode :16862, Total Frame : 20226124, Train reward : 28.0,
# Train Episode :16863, Total Frame : 20230008, Train reward : 26.0,
# Train Episode :16864, Total Frame : 20232628, Train reward : 23.0,
# Train Episode :16865, Total Frame : 20234572, Train reward : 36.0,
# Train Episode :16866, Total Frame : 20236860, Train reward : 19.0,
# Update Target
# Train Episode :16867, Total Frame : 20240068, Train reward : 26.0,
# Train Episode :16868, Total Frame : 20242792, Train reward : 17.0,
# Train Episode :16869, Total Frame : 20244892, Train reward : 12.0,
# ※Test※ 	 Frames: 2714 	 Score: 19.0
# Train Episode :16870, Total Frame : 20248964, Train reward : 39.0,
# Train Episode :16871, Total Frame : 20252004, Train reward : 38.0,
# Train Episode :16872, Total Frame : 20255376, Train reward : 40.0,
# Train Episode :16873, Total Frame : 20259916, Train reward : 37.0,
# Train Episode :16874, Total Frame : 20263072, Train reward : 19.0,
# Train Episode :16875, Total Frame : 20265604, Train reward : 15.0,
# Train Episode :16876, Total Frame : 20269876, Train reward : 42.0,
# Train Episode :16877, Total Frame : 20273064, Train reward : 31.0,
# Train Episode :16878, Total Frame : 20276516, Train reward : 26.0,
# Train Episode :16879, Total Frame : 20279284, Train reward : 17.0,
# ※Test※ 	 Frames: 1930 	 Score: 14.0
# Update Target
# Train Episode :16880, Total Frame : 20282600, Train reward : 32.0,
# Train Episode :16881, Total Frame : 20285560, Train reward : 47.0,
# Train Episode :16882, Total Frame : 20288300, Train reward : 17.0,
# Train Episode :16883, Total Frame : 20292004, Train reward : 45.0,
# Train Episode :16884, Total Frame : 20296596, Train reward : 56.0,
# Train Episode :16885, Total Frame : 20299556, Train reward : 21.0,
# Train Episode :16886, Total Frame : 20302128, Train reward : 19.0,
# Train Episode :16887, Total Frame : 20304436, Train reward : 17.0,
# Train Episode :16888, Total Frame : 20309528, Train reward : 49.0,
# Train Episode :16889, Total Frame : 20314428, Train reward : 72.0,
# ※Test※ 	 Frames: 2471 	 Score: 19.0
# Train Episode :16890, Total Frame : 20316844, Train reward : 18.0,
# Train Episode :16891, Total Frame : 20319560, Train reward : 19.0,
# Update Target
# Train Episode :16892, Total Frame : 20323768, Train reward : 43.0,
# Train Episode :16893, Total Frame : 20327012, Train reward : 22.0,
# Train Episode :16894, Total Frame : 20330928, Train reward : 38.0,
# Train Episode :16895, Total Frame : 20335400, Train reward : 38.0,
# Train Episode :16896, Total Frame : 20338080, Train reward : 38.0,
# Train Episode :16897, Total Frame : 20340556, Train reward : 41.0,
# Train Episode :16898, Total Frame : 20343220, Train reward : 22.0,
# Train Episode :16899, Total Frame : 20347708, Train reward : 42.0,
# ※Test※ 	 Frames: 3973 	 Score: 36.0
# Train Episode :16900, Total Frame : 20349776, Train reward : 13.0,
# Train Episode :16901, Total Frame : 20354424, Train reward : 51.0,
# Train Episode :16902, Total Frame : 20358468, Train reward : 44.0,
# Update Target
# Train Episode :16903, Total Frame : 20363076, Train reward : 57.0,
# Train Episode :16904, Total Frame : 20365600, Train reward : 38.0,
# Train Episode :16905, Total Frame : 20370740, Train reward : 61.0,
# Train Episode :16906, Total Frame : 20373928, Train reward : 31.0,
# Train Episode :16907, Total Frame : 20376336, Train reward : 42.0,
# Train Episode :16908, Total Frame : 20379444, Train reward : 23.0,
# Train Episode :16909, Total Frame : 20383548, Train reward : 45.0,
# ※Test※ 	 Frames: 3180 	 Score: 24.0
# Train Episode :16910, Total Frame : 20386596, Train reward : 19.0,
# Train Episode :16911, Total Frame : 20389124, Train reward : 43.0,
# Train Episode :16912, Total Frame : 20392640, Train reward : 24.0,
# Train Episode :16913, Total Frame : 20395312, Train reward : 30.0,
# Train Episode :16914, Total Frame : 20399056, Train reward : 23.0,
# Update Target
# Train Episode :16915, Total Frame : 20402312, Train reward : 32.0,
# Train Episode :16916, Total Frame : 20405288, Train reward : 45.0,
# Train Episode :16917, Total Frame : 20408044, Train reward : 36.0,
# Train Episode :16918, Total Frame : 20410248, Train reward : 16.0,
# Train Episode :16919, Total Frame : 20412640, Train reward : 27.0,
# ※Test※ 	 Frames: 2883 	 Score: 25.0
# Train Episode :16920, Total Frame : 20417412, Train reward : 47.0,
# Train Episode :16921, Total Frame : 20420036, Train reward : 34.0,
# Train Episode :16922, Total Frame : 20423568, Train reward : 47.0,
# Train Episode :16923, Total Frame : 20427420, Train reward : 30.0,
# Train Episode :16924, Total Frame : 20430668, Train reward : 31.0,
# Train Episode :16925, Total Frame : 20434076, Train reward : 26.0,
# Train Episode :16926, Total Frame : 20436232, Train reward : 13.0,
# Train Episode :16927, Total Frame : 20438368, Train reward : 13.0,
# Update Target
# Train Episode :16928, Total Frame : 20441772, Train reward : 49.0,
# Train Episode :16929, Total Frame : 20446464, Train reward : 35.0,
# ※Test※ 	 Frames: 3810 	 Score: 35.0
# Train Episode :16930, Total Frame : 20449632, Train reward : 36.0,
# Train Episode :16931, Total Frame : 20453476, Train reward : 37.0,
# Train Episode :16932, Total Frame : 20457744, Train reward : 36.0,
# Train Episode :16933, Total Frame : 20462176, Train reward : 50.0,
# Train Episode :16934, Total Frame : 20464356, Train reward : 34.0,
# Train Episode :16935, Total Frame : 20467604, Train reward : 47.0,
# Train Episode :16936, Total Frame : 20471156, Train reward : 27.0,
# Train Episode :16937, Total Frame : 20474908, Train reward : 26.0,
# Train Episode :16938, Total Frame : 20478644, Train reward : 34.0,
# Update Target
# Train Episode :16939, Total Frame : 20482276, Train reward : 28.0,
# ※Test※ 	 Frames: 2704 	 Score: 14.0
# Train Episode :16940, Total Frame : 20485440, Train reward : 23.0,
# Train Episode :16941, Total Frame : 20488324, Train reward : 32.0,
# Train Episode :16942, Total Frame : 20490728, Train reward : 18.0,
# Train Episode :16943, Total Frame : 20493664, Train reward : 22.0,
# Train Episode :16944, Total Frame : 20496288, Train reward : 14.0,
# Train Episode :16945, Total Frame : 20499348, Train reward : 23.0,
# Train Episode :16946, Total Frame : 20501848, Train reward : 16.0,
# Train Episode :16947, Total Frame : 20504608, Train reward : 16.0,
# Train Episode :16948, Total Frame : 20506880, Train reward : 12.0,
# Train Episode :16949, Total Frame : 20510984, Train reward : 45.0,
# ※Test※ 	 Frames: 2936 	 Score: 24.0
# Train Episode :16950, Total Frame : 20516080, Train reward : 50.0,
# Update Target
# Train Episode :16951, Total Frame : 20520460, Train reward : 32.0,
# Train Episode :16952, Total Frame : 20524072, Train reward : 30.0,
# Train Episode :16953, Total Frame : 20526592, Train reward : 15.0,
# Train Episode :16954, Total Frame : 20529476, Train reward : 29.0,
# Train Episode :16955, Total Frame : 20533028, Train reward : 21.0,
# Train Episode :16956, Total Frame : 20535800, Train reward : 25.0,
# Train Episode :16957, Total Frame : 20539528, Train reward : 31.0,
# Train Episode :16958, Total Frame : 20543744, Train reward : 33.0,
# Train Episode :16959, Total Frame : 20546780, Train reward : 27.0,
# ※Test※ 	 Frames: 2023 	 Score: 13.0
# Train Episode :16960, Total Frame : 20550272, Train reward : 33.0,
# Train Episode :16961, Total Frame : 20554312, Train reward : 40.0,
# Train Episode :16962, Total Frame : 20557324, Train reward : 23.0,
# Update Target
# Train Episode :16963, Total Frame : 20560760, Train reward : 35.0,
# Train Episode :16964, Total Frame : 20564456, Train reward : 29.0,
# Train Episode :16965, Total Frame : 20567088, Train reward : 17.0,
# Train Episode :16966, Total Frame : 20571412, Train reward : 33.0,
# Train Episode :16967, Total Frame : 20573848, Train reward : 17.0,
# Train Episode :16968, Total Frame : 20577696, Train reward : 37.0,
# Train Episode :16969, Total Frame : 20581496, Train reward : 33.0,
# ※Test※ 	 Frames: 3955 	 Score: 34.0
# Train Episode :16970, Total Frame : 20584096, Train reward : 19.0,
# Train Episode :16971, Total Frame : 20587640, Train reward : 25.0,
# Train Episode :16972, Total Frame : 20590756, Train reward : 24.0,
# Train Episode :16973, Total Frame : 20594212, Train reward : 25.0,
# Train Episode :16974, Total Frame : 20598468, Train reward : 45.0,
# Update Target
# Train Episode :16975, Total Frame : 20601656, Train reward : 41.0,
# Train Episode :16976, Total Frame : 20603592, Train reward : 14.0,
# Train Episode :16977, Total Frame : 20606208, Train reward : 15.0,
# Train Episode :16978, Total Frame : 20608916, Train reward : 18.0,
# Train Episode :16979, Total Frame : 20611852, Train reward : 21.0,
# ※Test※ 	 Frames: 3915 	 Score: 38.0
# Train Episode :16980, Total Frame : 20616292, Train reward : 40.0,
# Train Episode :16981, Total Frame : 20620112, Train reward : 30.0,
# Train Episode :16982, Total Frame : 20622924, Train reward : 40.0,
# Train Episode :16983, Total Frame : 20626252, Train reward : 40.0,
# Train Episode :16984, Total Frame : 20629816, Train reward : 36.0,
# Train Episode :16985, Total Frame : 20634456, Train reward : 48.0,
# Train Episode :16986, Total Frame : 20639084, Train reward : 39.0,
# Update Target
# Train Episode :16987, Total Frame : 20641800, Train reward : 23.0,
# Train Episode :16988, Total Frame : 20643988, Train reward : 17.0,
# Train Episode :16989, Total Frame : 20646916, Train reward : 21.0,
# ※Test※ 	 Frames: 3611 	 Score: 33.0
# Train Episode :16990, Total Frame : 20650572, Train reward : 32.0,
# Train Episode :16991, Total Frame : 20653540, Train reward : 22.0,
# Train Episode :16992, Total Frame : 20656024, Train reward : 38.0,
# Train Episode :16993, Total Frame : 20659192, Train reward : 46.0,
# Train Episode :16994, Total Frame : 20662176, Train reward : 25.0,
# Train Episode :16995, Total Frame : 20664440, Train reward : 16.0,
# Train Episode :16996, Total Frame : 20668568, Train reward : 35.0,
# Train Episode :16997, Total Frame : 20670568, Train reward : 13.0,
# Train Episode :16998, Total Frame : 20672944, Train reward : 14.0,
# Train Episode :16999, Total Frame : 20677056, Train reward : 43.0,
# ※Test※ 	 Frames: 4329 	 Score: 39.0
# Update Target
# Train Episode :17000, Total Frame : 20680608, Train reward : 41.0,
# Train Episode :17001, Total Frame : 20684088, Train reward : 41.0,
# Train Episode :17002, Total Frame : 20687956, Train reward : 35.0,
# Train Episode :17003, Total Frame : 20690648, Train reward : 16.0,
# Train Episode :17004, Total Frame : 20694520, Train reward : 47.0,
# Train Episode :17005, Total Frame : 20696812, Train reward : 14.0,
# Train Episode :17006, Total Frame : 20699276, Train reward : 35.0,
# Train Episode :17007, Total Frame : 20702284, Train reward : 21.0,
# Train Episode :17008, Total Frame : 20706604, Train reward : 39.0,
# Train Episode :17009, Total Frame : 20710164, Train reward : 34.0,
# ※Test※ 	 Frames: 3665 	 Score: 33.0
# Train Episode :17010, Total Frame : 20712620, Train reward : 20.0,
# Train Episode :17011, Total Frame : 20715432, Train reward : 21.0,
# Train Episode :17012, Total Frame : 20717908, Train reward : 25.0,
# Train Episode :17013, Total Frame : 20719976, Train reward : 40.0,
# Update Target
# Train Episode :17014, Total Frame : 20723176, Train reward : 18.0,
# Train Episode :17015, Total Frame : 20726260, Train reward : 21.0,
# Train Episode :17016, Total Frame : 20729648, Train reward : 22.0,
# Train Episode :17017, Total Frame : 20733552, Train reward : 40.0,
# Train Episode :17018, Total Frame : 20737880, Train reward : 50.0,
# Train Episode :17019, Total Frame : 20740432, Train reward : 18.0,
# ※Test※ 	 Frames: 3367 	 Score: 46.0
# Train Episode :17020, Total Frame : 20743828, Train reward : 42.0,
# Train Episode :17021, Total Frame : 20745728, Train reward : 10.0,
# Train Episode :17022, Total Frame : 20748048, Train reward : 13.0,
# Train Episode :17023, Total Frame : 20752524, Train reward : 59.0,
# Train Episode :17024, Total Frame : 20757596, Train reward : 48.0,
# Update Target
# Train Episode :17025, Total Frame : 20761248, Train reward : 32.0,
# Train Episode :17026, Total Frame : 20763544, Train reward : 14.0,
# Train Episode :17027, Total Frame : 20766488, Train reward : 27.0,
# Train Episode :17028, Total Frame : 20769736, Train reward : 21.0,
# Train Episode :17029, Total Frame : 20772828, Train reward : 28.0,
# ※Test※ 	 Frames: 3462 	 Score: 28.0
# Train Episode :17030, Total Frame : 20775404, Train reward : 42.0,
# Train Episode :17031, Total Frame : 20778752, Train reward : 29.0,
# Train Episode :17032, Total Frame : 20783172, Train reward : 41.0,
# Train Episode :17033, Total Frame : 20787912, Train reward : 46.0,
# Train Episode :17034, Total Frame : 20791636, Train reward : 33.0,
# Train Episode :17035, Total Frame : 20794016, Train reward : 14.0,
# Train Episode :17036, Total Frame : 20796056, Train reward : 11.0,
# Train Episode :17037, Total Frame : 20799312, Train reward : 24.0,
# Update Target
# Train Episode :17038, Total Frame : 20803724, Train reward : 36.0,
# Train Episode :17039, Total Frame : 20807068, Train reward : 39.0,
# ※Test※ 	 Frames: 2769 	 Score: 21.0
# Train Episode :17040, Total Frame : 20809136, Train reward : 17.0,
# Train Episode :17041, Total Frame : 20813084, Train reward : 35.0,
# Train Episode :17042, Total Frame : 20815508, Train reward : 15.0,
# Train Episode :17043, Total Frame : 20817748, Train reward : 12.0,
# Train Episode :17044, Total Frame : 20821232, Train reward : 34.0,
# Train Episode :17045, Total Frame : 20823520, Train reward : 14.0,
# Train Episode :17046, Total Frame : 20827328, Train reward : 33.0,
# Train Episode :17047, Total Frame : 20830340, Train reward : 25.0,
# Train Episode :17048, Total Frame : 20833616, Train reward : 26.0,
# Train Episode :17049, Total Frame : 20837568, Train reward : 33.0,
# ※Test※ 	 Frames: 4964 	 Score: 57.0
# Train Episode :17050, Total Frame : 20839936, Train reward : 14.0,
# Update Target
# Train Episode :17051, Total Frame : 20842936, Train reward : 24.0,
# Train Episode :17052, Total Frame : 20846136, Train reward : 31.0,
# Train Episode :17053, Total Frame : 20849660, Train reward : 38.0,
# Train Episode :17054, Total Frame : 20852452, Train reward : 40.0,
# Train Episode :17055, Total Frame : 20856664, Train reward : 52.0,
# Train Episode :17056, Total Frame : 20860192, Train reward : 28.0,
# Train Episode :17057, Total Frame : 20863052, Train reward : 27.0,
# Train Episode :17058, Total Frame : 20867324, Train reward : 36.0,
# Train Episode :17059, Total Frame : 20871008, Train reward : 21.0,
# ※Test※ 	 Frames: 4659 	 Score: 50.0
# Train Episode :17060, Total Frame : 20874248, Train reward : 36.0,
# Train Episode :17061, Total Frame : 20877712, Train reward : 21.0,
# Update Target
# Train Episode :17062, Total Frame : 20880128, Train reward : 19.0,
# Train Episode :17063, Total Frame : 20883056, Train reward : 24.0,
# Train Episode :17064, Total Frame : 20886376, Train reward : 20.0,
# Train Episode :17065, Total Frame : 20888272, Train reward : 16.0,
# Train Episode :17066, Total Frame : 20890672, Train reward : 15.0,
# Train Episode :17067, Total Frame : 20894332, Train reward : 40.0,
# Train Episode :17068, Total Frame : 20897608, Train reward : 41.0,
# Train Episode :17069, Total Frame : 20902952, Train reward : 88.0,
# ※Test※ 	 Frames: 2480 	 Score: 20.0
# Train Episode :17070, Total Frame : 20906700, Train reward : 30.0,
# Train Episode :17071, Total Frame : 20911180, Train reward : 33.0,
# Train Episode :17072, Total Frame : 20915804, Train reward : 45.0,
# Train Episode :17073, Total Frame : 20918644, Train reward : 23.0,
# Update Target
# Train Episode :17074, Total Frame : 20921636, Train reward : 21.0,
# Train Episode :17075, Total Frame : 20926180, Train reward : 37.0,
# Train Episode :17076, Total Frame : 20929692, Train reward : 31.0,
# Train Episode :17077, Total Frame : 20931584, Train reward : 11.0,
# Train Episode :17078, Total Frame : 20933604, Train reward : 19.0,
# Train Episode :17079, Total Frame : 20936120, Train reward : 18.0,
# ※Test※ 	 Frames: 3937 	 Score: 41.0
# Train Episode :17080, Total Frame : 20938576, Train reward : 15.0,
# Train Episode :17081, Total Frame : 20941772, Train reward : 28.0,
# Train Episode :17082, Total Frame : 20946240, Train reward : 34.0,
# Train Episode :17083, Total Frame : 20949164, Train reward : 38.0,
# Train Episode :17084, Total Frame : 20951040, Train reward : 22.0,
# Train Episode :17085, Total Frame : 20955180, Train reward : 31.0,
# Train Episode :17086, Total Frame : 20957976, Train reward : 32.0,
# Update Target
# Train Episode :17087, Total Frame : 20961648, Train reward : 28.0,
# Train Episode :17088, Total Frame : 20964316, Train reward : 23.0,
# Train Episode :17089, Total Frame : 20966284, Train reward : 11.0,
# ※Test※ 	 Frames: 2471 	 Score: 38.0
# Train Episode :17090, Total Frame : 20968712, Train reward : 15.0,
# Train Episode :17091, Total Frame : 20970964, Train reward : 16.0,
# Train Episode :17092, Total Frame : 20974224, Train reward : 21.0,
# Train Episode :17093, Total Frame : 20976180, Train reward : 11.0,
# Train Episode :17094, Total Frame : 20979292, Train reward : 23.0,
# Train Episode :17095, Total Frame : 20982280, Train reward : 22.0,
# Train Episode :17096, Total Frame : 20985488, Train reward : 23.0,
# Train Episode :17097, Total Frame : 20991200, Train reward : 49.0,
# Train Episode :17098, Total Frame : 20994844, Train reward : 27.0,
# Train Episode :17099, Total Frame : 20999492, Train reward : 49.0,
# ※Test※ 	 Frames: 3930 	 Score: 23.0
# Update Target
# Train Episode :17100, Total Frame : 21003876, Train reward : 53.0,
# Train Episode :17101, Total Frame : 21006304, Train reward : 36.0,
# Train Episode :17102, Total Frame : 21009056, Train reward : 16.0,
# Train Episode :17103, Total Frame : 21011612, Train reward : 16.0,
# Train Episode :17104, Total Frame : 21015172, Train reward : 34.0,
# Train Episode :17105, Total Frame : 21017772, Train reward : 24.0,
# Train Episode :17106, Total Frame : 21019904, Train reward : 45.0,
# Train Episode :17107, Total Frame : 21022568, Train reward : 53.0,
# Train Episode :17108, Total Frame : 21026364, Train reward : 28.0,
# Train Episode :17109, Total Frame : 21029404, Train reward : 21.0,
# ※Test※ 	 Frames: 2550 	 Score: 19.0
# Train Episode :17110, Total Frame : 21033656, Train reward : 39.0,
# Train Episode :17111, Total Frame : 21038216, Train reward : 33.0,
# Update Target
# Train Episode :17112, Total Frame : 21041560, Train reward : 25.0,
# Train Episode :17113, Total Frame : 21044588, Train reward : 32.0,
# Train Episode :17114, Total Frame : 21049952, Train reward : 50.0,
# Train Episode :17115, Total Frame : 21052548, Train reward : 16.0,
# Train Episode :17116, Total Frame : 21055440, Train reward : 45.0,
# Train Episode :17117, Total Frame : 21058524, Train reward : 236.0,
# Train Episode :17118, Total Frame : 21061460, Train reward : 27.0,
# Train Episode :17119, Total Frame : 21064296, Train reward : 23.0,
# ※Test※ 	 Frames: 3162 	 Score: 34.0
# Train Episode :17120, Total Frame : 21068240, Train reward : 45.0,
# Train Episode :17121, Total Frame : 21073592, Train reward : 58.0,
# Train Episode :17122, Total Frame : 21076516, Train reward : 25.0,
# Train Episode :17123, Total Frame : 21079248, Train reward : 17.0,
# Update Target
# Train Episode :17124, Total Frame : 21082444, Train reward : 19.0,
# Train Episode :17125, Total Frame : 21084232, Train reward : 16.0,
# Train Episode :17126, Total Frame : 21087472, Train reward : 24.0,
# Train Episode :17127, Total Frame : 21090312, Train reward : 32.0,
# Train Episode :17128, Total Frame : 21093376, Train reward : 36.0,
# Train Episode :17129, Total Frame : 21095544, Train reward : 37.0,
# ※Test※ 	 Frames: 3849 	 Score: 29.0
# Train Episode :17130, Total Frame : 21099904, Train reward : 39.0,
# Train Episode :17131, Total Frame : 21103248, Train reward : 27.0,
# Train Episode :17132, Total Frame : 21106228, Train reward : 28.0,
# Train Episode :17133, Total Frame : 21109924, Train reward : 31.0,
# Train Episode :17134, Total Frame : 21113136, Train reward : 24.0,
# Train Episode :17135, Total Frame : 21116032, Train reward : 22.0,
# Train Episode :17136, Total Frame : 21118504, Train reward : 14.0,
# Update Target
# Train Episode :17137, Total Frame : 21121832, Train reward : 31.0,
# Train Episode :17138, Total Frame : 21126144, Train reward : 36.0,
# Train Episode :17139, Total Frame : 21129360, Train reward : 53.0,
# ※Test※ 	 Frames: 5890 	 Score: 61.0
# Train Episode :17140, Total Frame : 21131760, Train reward : 35.0,
# Train Episode :17141, Total Frame : 21134948, Train reward : 25.0,
# Train Episode :17142, Total Frame : 21138604, Train reward : 31.0,
# Train Episode :17143, Total Frame : 21141476, Train reward : 67.0,
# Train Episode :17144, Total Frame : 21144924, Train reward : 55.0,
# Train Episode :17145, Total Frame : 21148428, Train reward : 46.0,
# Train Episode :17146, Total Frame : 21151032, Train reward : 15.0,
# Train Episode :17147, Total Frame : 21155032, Train reward : 46.0,
# Train Episode :17148, Total Frame : 21158076, Train reward : 32.0,
# Update Target
# Train Episode :17149, Total Frame : 21160580, Train reward : 14.0,
# ※Test※ 	 Frames: 3471 	 Score: 32.0
# Train Episode :17150, Total Frame : 21163792, Train reward : 26.0,
# Train Episode :17151, Total Frame : 21166500, Train reward : 18.0,
# Train Episode :17152, Total Frame : 21169880, Train reward : 27.0,
# Train Episode :17153, Total Frame : 21174148, Train reward : 38.0,
# Train Episode :17154, Total Frame : 21178020, Train reward : 37.0,
# Train Episode :17155, Total Frame : 21180608, Train reward : 17.0,
# Train Episode :17156, Total Frame : 21182236, Train reward : 28.0,
# Train Episode :17157, Total Frame : 21186628, Train reward : 65.0,
# Train Episode :17158, Total Frame : 21189184, Train reward : 28.0,
# Train Episode :17159, Total Frame : 21190740, Train reward : 8.0,
# ※Test※ 	 Frames: 3015 	 Score: 36.0
# Train Episode :17160, Total Frame : 21195100, Train reward : 43.0,
# Train Episode :17161, Total Frame : 21199160, Train reward : 35.0,
# Update Target
# Train Episode :17162, Total Frame : 21201848, Train reward : 18.0,
# Train Episode :17163, Total Frame : 21205552, Train reward : 33.0,
# Train Episode :17164, Total Frame : 21209840, Train reward : 68.0,
# Train Episode :17165, Total Frame : 21212856, Train reward : 23.0,
# Train Episode :17166, Total Frame : 21215488, Train reward : 15.0,
# Train Episode :17167, Total Frame : 21219276, Train reward : 32.0,
# Train Episode :17168, Total Frame : 21221216, Train reward : 11.0,
# Train Episode :17169, Total Frame : 21225076, Train reward : 30.0,
# ※Test※ 	 Frames: 3038 	 Score: 38.0
# Train Episode :17170, Total Frame : 21227456, Train reward : 16.0,
# Train Episode :17171, Total Frame : 21229800, Train reward : 24.0,
# Train Episode :17172, Total Frame : 21234064, Train reward : 41.0,
# Train Episode :17173, Total Frame : 21237404, Train reward : 47.0,
# Update Target
# Train Episode :17174, Total Frame : 21241888, Train reward : 39.0,
# Train Episode :17175, Total Frame : 21244576, Train reward : 42.0,
# Train Episode :17176, Total Frame : 21248232, Train reward : 33.0,
# Train Episode :17177, Total Frame : 21251680, Train reward : 24.0,
# Train Episode :17178, Total Frame : 21253724, Train reward : 19.0,
# Train Episode :17179, Total Frame : 21257084, Train reward : 29.0,
# ※Test※ 	 Frames: 4079 	 Score: 44.0
# Train Episode :17180, Total Frame : 21261660, Train reward : 65.0,
# Train Episode :17181, Total Frame : 21264836, Train reward : 78.0,
# Train Episode :17182, Total Frame : 21269124, Train reward : 39.0,
# Train Episode :17183, Total Frame : 21272292, Train reward : 22.0,
# Train Episode :17184, Total Frame : 21274528, Train reward : 40.0,
# Train Episode :17185, Total Frame : 21277260, Train reward : 23.0,
# Update Target
# Train Episode :17186, Total Frame : 21280800, Train reward : 23.0,
# Train Episode :17187, Total Frame : 21284652, Train reward : 30.0,
# Train Episode :17188, Total Frame : 21286936, Train reward : 26.0,
# Train Episode :17189, Total Frame : 21291052, Train reward : 42.0,
# ※Test※ 	 Frames: 2987 	 Score: 20.0
# Train Episode :17190, Total Frame : 21294804, Train reward : 42.0,
# Train Episode :17191, Total Frame : 21298184, Train reward : 22.0,
# Train Episode :17192, Total Frame : 21301672, Train reward : 46.0,
# Train Episode :17193, Total Frame : 21305008, Train reward : 44.0,
# Train Episode :17194, Total Frame : 21308304, Train reward : 40.0,
# Train Episode :17195, Total Frame : 21311932, Train reward : 26.0,
# Train Episode :17196, Total Frame : 21315520, Train reward : 28.0,
# Train Episode :17197, Total Frame : 21318944, Train reward : 26.0,
# Update Target
# Train Episode :17198, Total Frame : 21322532, Train reward : 26.0,
# Train Episode :17199, Total Frame : 21326840, Train reward : 38.0,
# ※Test※ 	 Frames: 3363 	 Score: 29.0
# Train Episode :17200, Total Frame : 21331000, Train reward : 38.0,
# Train Episode :17201, Total Frame : 21332996, Train reward : 11.0,
# Train Episode :17202, Total Frame : 21337664, Train reward : 43.0,
# Train Episode :17203, Total Frame : 21341816, Train reward : 33.0,
# Train Episode :17204, Total Frame : 21344884, Train reward : 27.0,
# Train Episode :17205, Total Frame : 21349468, Train reward : 52.0,
# Train Episode :17206, Total Frame : 21353464, Train reward : 41.0,
# Train Episode :17207, Total Frame : 21358336, Train reward : 36.0,
# Update Target
# Train Episode :17208, Total Frame : 21361236, Train reward : 25.0,
# Train Episode :17209, Total Frame : 21363740, Train reward : 15.0,
# ※Test※ 	 Frames: 3462 	 Score: 34.0
# Train Episode :17210, Total Frame : 21365624, Train reward : 11.0,
# Train Episode :17211, Total Frame : 21368232, Train reward : 33.0,
# Train Episode :17212, Total Frame : 21371844, Train reward : 238.0,
# Train Episode :17213, Total Frame : 21375708, Train reward : 31.0,
# Train Episode :17214, Total Frame : 21378468, Train reward : 29.0,
# Train Episode :17215, Total Frame : 21381188, Train reward : 20.0,
# Train Episode :17216, Total Frame : 21383540, Train reward : 17.0,
# Train Episode :17217, Total Frame : 21387804, Train reward : 35.0,
# Train Episode :17218, Total Frame : 21392444, Train reward : 63.0,
# Train Episode :17219, Total Frame : 21395572, Train reward : 22.0,
# ※Test※ 	 Frames: 3401 	 Score: 24.0
# Train Episode :17220, Total Frame : 21399908, Train reward : 35.0,
# Update Target
# Train Episode :17221, Total Frame : 21402824, Train reward : 17.0,
# Train Episode :17222, Total Frame : 21406480, Train reward : 29.0,
# Train Episode :17223, Total Frame : 21408776, Train reward : 40.0,
# Train Episode :17224, Total Frame : 21412096, Train reward : 28.0,
# Train Episode :17225, Total Frame : 21415708, Train reward : 26.0,
# Train Episode :17226, Total Frame : 21419516, Train reward : 245.0,
# Train Episode :17227, Total Frame : 21423396, Train reward : 38.0,
# Train Episode :17228, Total Frame : 21427532, Train reward : 54.0,
# Train Episode :17229, Total Frame : 21430492, Train reward : 28.0,
# ※Test※ 	 Frames: 5424 	 Score: 50.0
# Train Episode :17230, Total Frame : 21434860, Train reward : 37.0,
# Train Episode :17231, Total Frame : 21437548, Train reward : 22.0,
# Update Target
# Train Episode :17232, Total Frame : 21441636, Train reward : 28.0,
# Train Episode :17233, Total Frame : 21444120, Train reward : 22.0,
# Train Episode :17234, Total Frame : 21447220, Train reward : 29.0,
# Train Episode :17235, Total Frame : 21449780, Train reward : 36.0,
# Train Episode :17236, Total Frame : 21453688, Train reward : 32.0,
# Train Episode :17237, Total Frame : 21457248, Train reward : 35.0,
# Train Episode :17238, Total Frame : 21459748, Train reward : 42.0,
# Train Episode :17239, Total Frame : 21463444, Train reward : 29.0,
# ※Test※ 	 Frames: 2856 	 Score: 24.0
# Train Episode :17240, Total Frame : 21467268, Train reward : 30.0,
# Train Episode :17241, Total Frame : 21469504, Train reward : 16.0,
# Train Episode :17242, Total Frame : 21472952, Train reward : 32.0,
# Train Episode :17243, Total Frame : 21477024, Train reward : 42.0,
# Update Target
# Train Episode :17244, Total Frame : 21480828, Train reward : 32.0,
# Train Episode :17245, Total Frame : 21484548, Train reward : 25.0,
# Train Episode :17246, Total Frame : 21486912, Train reward : 42.0,
# Train Episode :17247, Total Frame : 21490024, Train reward : 68.0,
# Train Episode :17248, Total Frame : 21493464, Train reward : 25.0,
# Train Episode :17249, Total Frame : 21498236, Train reward : 41.0,
# ※Test※ 	 Frames: 1647 	 Score: 10.0
# Train Episode :17250, Total Frame : 21501796, Train reward : 25.0,
# Train Episode :17251, Total Frame : 21504164, Train reward : 33.0,
# Train Episode :17252, Total Frame : 21505996, Train reward : 13.0,
# Train Episode :17253, Total Frame : 21509116, Train reward : 22.0,
# Train Episode :17254, Total Frame : 21512936, Train reward : 44.0,
# Train Episode :17255, Total Frame : 21518328, Train reward : 55.0,
# Update Target
# Train Episode :17256, Total Frame : 21522164, Train reward : 37.0,
# Train Episode :17257, Total Frame : 21526032, Train reward : 45.0,
# Train Episode :17258, Total Frame : 21529928, Train reward : 37.0,
# Train Episode :17259, Total Frame : 21533808, Train reward : 40.0,
# ※Test※ 	 Frames: 1748 	 Score: 23.0
# Train Episode :17260, Total Frame : 21536796, Train reward : 24.0,
# Train Episode :17261, Total Frame : 21539372, Train reward : 17.0,
# Train Episode :17262, Total Frame : 21542460, Train reward : 21.0,
# Train Episode :17263, Total Frame : 21545512, Train reward : 23.0,
# Train Episode :17264, Total Frame : 21547552, Train reward : 12.0,
# Train Episode :17265, Total Frame : 21550524, Train reward : 23.0,
# Train Episode :17266, Total Frame : 21555712, Train reward : 56.0,
# Train Episode :17267, Total Frame : 21558132, Train reward : 17.0,
# Update Target
# Train Episode :17268, Total Frame : 21560300, Train reward : 12.0,
# Train Episode :17269, Total Frame : 21563932, Train reward : 30.0,
# ※Test※ 	 Frames: 3239 	 Score: 37.0
# Train Episode :17270, Total Frame : 21567364, Train reward : 34.0,
# Train Episode :17271, Total Frame : 21571836, Train reward : 47.0,
# Train Episode :17272, Total Frame : 21576524, Train reward : 42.0,
# Train Episode :17273, Total Frame : 21579192, Train reward : 19.0,
# Train Episode :17274, Total Frame : 21581936, Train reward : 25.0,
# Train Episode :17275, Total Frame : 21586104, Train reward : 36.0,
# Train Episode :17276, Total Frame : 21589948, Train reward : 36.0,
# Train Episode :17277, Total Frame : 21592624, Train reward : 15.0,
# Train Episode :17278, Total Frame : 21595860, Train reward : 20.0,
# Train Episode :17279, Total Frame : 21599416, Train reward : 32.0,
# ※Test※ 	 Frames: 3721 	 Score: 33.0
# Update Target
# Train Episode :17280, Total Frame : 21602184, Train reward : 18.0,
# Train Episode :17281, Total Frame : 21605124, Train reward : 18.0,
# Train Episode :17282, Total Frame : 21609004, Train reward : 30.0,
# Train Episode :17283, Total Frame : 21611540, Train reward : 45.0,
# Train Episode :17284, Total Frame : 21615420, Train reward : 30.0,
# Train Episode :17285, Total Frame : 21618200, Train reward : 25.0,
# Train Episode :17286, Total Frame : 21620460, Train reward : 16.0,
# Train Episode :17287, Total Frame : 21623592, Train reward : 29.0,
# Train Episode :17288, Total Frame : 21626888, Train reward : 37.0,
# Train Episode :17289, Total Frame : 21629196, Train reward : 33.0,
# ※Test※ 	 Frames: 3105 	 Score: 38.0
# Train Episode :17290, Total Frame : 21633332, Train reward : 48.0,
# Train Episode :17291, Total Frame : 21637684, Train reward : 43.0,
# Update Target
# Train Episode :17292, Total Frame : 21641224, Train reward : 30.0,
# Train Episode :17293, Total Frame : 21645888, Train reward : 47.0,
# Train Episode :17294, Total Frame : 21648700, Train reward : 36.0,
# Train Episode :17295, Total Frame : 21651916, Train reward : 81.0,
# Train Episode :17296, Total Frame : 21656592, Train reward : 41.0,
# Train Episode :17297, Total Frame : 21659768, Train reward : 29.0,
# Train Episode :17298, Total Frame : 21662512, Train reward : 22.0,
# Train Episode :17299, Total Frame : 21666268, Train reward : 26.0,
# ※Test※ 	 Frames: 3622 	 Score: 34.0
# Train Episode :17300, Total Frame : 21668876, Train reward : 15.0,
# Train Episode :17301, Total Frame : 21672576, Train reward : 28.0,
# Train Episode :17302, Total Frame : 21678096, Train reward : 51.0,
# Update Target
# Train Episode :17303, Total Frame : 21680928, Train reward : 32.0,
# Train Episode :17304, Total Frame : 21685264, Train reward : 35.0,
# Train Episode :17305, Total Frame : 21688844, Train reward : 29.0,
# Train Episode :17306, Total Frame : 21691724, Train reward : 23.0,
# Train Episode :17307, Total Frame : 21693864, Train reward : 13.0,
# Train Episode :17308, Total Frame : 21696708, Train reward : 20.0,
# Train Episode :17309, Total Frame : 21700312, Train reward : 36.0,
# ※Test※ 	 Frames: 3607 	 Score: 30.0
# Train Episode :17310, Total Frame : 21702516, Train reward : 11.0,
# Train Episode :17311, Total Frame : 21704332, Train reward : 34.0,
# Train Episode :17312, Total Frame : 21706812, Train reward : 22.0,
# Train Episode :17313, Total Frame : 21710008, Train reward : 26.0,
# Train Episode :17314, Total Frame : 21714340, Train reward : 45.0,
# Train Episode :17315, Total Frame : 21719008, Train reward : 50.0,
# Update Target
# Train Episode :17316, Total Frame : 21722844, Train reward : 52.0,
# Train Episode :17317, Total Frame : 21726484, Train reward : 35.0,
# Train Episode :17318, Total Frame : 21730656, Train reward : 29.0,
# Train Episode :17319, Total Frame : 21734720, Train reward : 42.0,
# ※Test※ 	 Frames: 3134 	 Score: 27.0
# Train Episode :17320, Total Frame : 21737980, Train reward : 30.0,
# Train Episode :17321, Total Frame : 21741828, Train reward : 39.0,
# Train Episode :17322, Total Frame : 21745992, Train reward : 59.0,
# Train Episode :17323, Total Frame : 21749420, Train reward : 25.0,
# Train Episode :17324, Total Frame : 21751688, Train reward : 23.0,
# Train Episode :17325, Total Frame : 21754820, Train reward : 24.0,
# Train Episode :17326, Total Frame : 21759564, Train reward : 43.0,
# Update Target
# Train Episode :17327, Total Frame : 21765008, Train reward : 53.0,
# Train Episode :17328, Total Frame : 21768636, Train reward : 46.0,
# Train Episode :17329, Total Frame : 21770744, Train reward : 148.0,
# ※Test※ 	 Frames: 4421 	 Score: 43.0
# Train Episode :17330, Total Frame : 21775792, Train reward : 50.0,
# Train Episode :17331, Total Frame : 21780812, Train reward : 45.0,
# Train Episode :17332, Total Frame : 21785676, Train reward : 48.0,
# Train Episode :17333, Total Frame : 21788220, Train reward : 15.0,
# Train Episode :17334, Total Frame : 21790964, Train reward : 21.0,
# Train Episode :17335, Total Frame : 21795272, Train reward : 57.0,
# Train Episode :17336, Total Frame : 21799112, Train reward : 35.0,
# Update Target
# Train Episode :17337, Total Frame : 21801804, Train reward : 17.0,
# Train Episode :17338, Total Frame : 21804940, Train reward : 25.0,
# Train Episode :17339, Total Frame : 21808768, Train reward : 30.0,
# ※Test※ 	 Frames: 3403 	 Score: 24.0
# Train Episode :17340, Total Frame : 21813496, Train reward : 41.0,
# Train Episode :17341, Total Frame : 21817416, Train reward : 51.0,
# Train Episode :17342, Total Frame : 21821612, Train reward : 39.0,
# Train Episode :17343, Total Frame : 21823712, Train reward : 12.0,
# Train Episode :17344, Total Frame : 21826276, Train reward : 15.0,
# Train Episode :17345, Total Frame : 21831016, Train reward : 38.0,
# Train Episode :17346, Total Frame : 21833728, Train reward : 27.0,
# Train Episode :17347, Total Frame : 21837176, Train reward : 27.0,
# Update Target
# Train Episode :17348, Total Frame : 21841520, Train reward : 51.0,
# Train Episode :17349, Total Frame : 21844064, Train reward : 31.0,
# ※Test※ 	 Frames: 3114 	 Score: 22.0
# Train Episode :17350, Total Frame : 21847740, Train reward : 26.0,
# Train Episode :17351, Total Frame : 21851464, Train reward : 39.0,
# Train Episode :17352, Total Frame : 21854736, Train reward : 23.0,
# Train Episode :17353, Total Frame : 21856980, Train reward : 16.0,
# Train Episode :17354, Total Frame : 21860256, Train reward : 31.0,
# Train Episode :17355, Total Frame : 21862580, Train reward : 25.0,
# Train Episode :17356, Total Frame : 21867944, Train reward : 63.0,
# Train Episode :17357, Total Frame : 21872316, Train reward : 34.0,
# Train Episode :17358, Total Frame : 21874788, Train reward : 14.0,
# Update Target
# Train Episode :17359, Total Frame : 21880000, Train reward : 57.0,
# ※Test※ 	 Frames: 3064 	 Score: 28.0
# Train Episode :17360, Total Frame : 21883028, Train reward : 44.0,
# Train Episode :17361, Total Frame : 21886892, Train reward : 37.0,
# Train Episode :17362, Total Frame : 21890060, Train reward : 28.0,
# Train Episode :17363, Total Frame : 21893348, Train reward : 20.0,
# Train Episode :17364, Total Frame : 21895788, Train reward : 31.0,
# Train Episode :17365, Total Frame : 21899692, Train reward : 33.0,
# Train Episode :17366, Total Frame : 21904208, Train reward : 46.0,
# Train Episode :17367, Total Frame : 21908636, Train reward : 38.0,
# Train Episode :17368, Total Frame : 21911588, Train reward : 18.0,
# Train Episode :17369, Total Frame : 21915944, Train reward : 35.0,
# ※Test※ 	 Frames: 2680 	 Score: 30.0
# Update Target
# Train Episode :17370, Total Frame : 21920196, Train reward : 69.0,
# Train Episode :17371, Total Frame : 21923204, Train reward : 27.0,
# Train Episode :17372, Total Frame : 21928692, Train reward : 62.0,
# Train Episode :17373, Total Frame : 21933292, Train reward : 43.0,
# Train Episode :17374, Total Frame : 21936056, Train reward : 25.0,
# Train Episode :17375, Total Frame : 21940108, Train reward : 39.0,
# Train Episode :17376, Total Frame : 21943676, Train reward : 27.0,
# Train Episode :17377, Total Frame : 21946536, Train reward : 27.0,
# Train Episode :17378, Total Frame : 21950008, Train reward : 42.0,
# Train Episode :17379, Total Frame : 21953092, Train reward : 18.0,
# ※Test※ 	 Frames: 2733 	 Score: 12.0
# Train Episode :17380, Total Frame : 21957644, Train reward : 46.0,
# Update Target
# Train Episode :17381, Total Frame : 21961728, Train reward : 46.0,
# Train Episode :17382, Total Frame : 21966228, Train reward : 45.0,
# Train Episode :17383, Total Frame : 21969784, Train reward : 37.0,
# Train Episode :17384, Total Frame : 21973188, Train reward : 35.0,
# Train Episode :17385, Total Frame : 21977092, Train reward : 38.0,
# Train Episode :17386, Total Frame : 21980628, Train reward : 28.0,
# Train Episode :17387, Total Frame : 21983348, Train reward : 15.0,
# Train Episode :17388, Total Frame : 21989148, Train reward : 65.0,
# Train Episode :17389, Total Frame : 21993320, Train reward : 33.0,
# ※Test※ 	 Frames: 3949 	 Score: 44.0
# Train Episode :17390, Total Frame : 21999048, Train reward : 70.0,
# Update Target
# Train Episode :17391, Total Frame : 22002916, Train reward : 36.0,
# Train Episode :17392, Total Frame : 22007064, Train reward : 39.0,
# Train Episode :17393, Total Frame : 22010928, Train reward : 32.0,
# Train Episode :17394, Total Frame : 22014576, Train reward : 29.0,
# Train Episode :17395, Total Frame : 22018512, Train reward : 31.0,
# Train Episode :17396, Total Frame : 22022384, Train reward : 28.0,
# Train Episode :17397, Total Frame : 22026960, Train reward : 223.0,
# Train Episode :17398, Total Frame : 22031500, Train reward : 41.0,
# Train Episode :17399, Total Frame : 22035328, Train reward : 48.0,
# ※Test※ 	 Frames: 4227 	 Score: 50.0
# Train Episode :17400, Total Frame : 22038344, Train reward : 48.0,
# Update Target
# Train Episode :17401, Total Frame : 22040808, Train reward : 21.0,
# Train Episode :17402, Total Frame : 22042916, Train reward : 26.0,
# Train Episode :17403, Total Frame : 22047792, Train reward : 57.0,
# Train Episode :17404, Total Frame : 22051116, Train reward : 41.0,
# Train Episode :17405, Total Frame : 22055168, Train reward : 31.0,
# Train Episode :17406, Total Frame : 22059200, Train reward : 28.0,
# Train Episode :17407, Total Frame : 22061856, Train reward : 16.0,
# Train Episode :17408, Total Frame : 22065012, Train reward : 27.0,
# Train Episode :17409, Total Frame : 22068484, Train reward : 29.0,
# ※Test※ 	 Frames: 3736 	 Score: 40.0
# Train Episode :17410, Total Frame : 22073424, Train reward : 53.0,
# Train Episode :17411, Total Frame : 22077292, Train reward : 160.0,
# Update Target
# Train Episode :17412, Total Frame : 22081580, Train reward : 48.0,
# Train Episode :17413, Total Frame : 22085932, Train reward : 33.0,
# Train Episode :17414, Total Frame : 22090784, Train reward : 59.0,
# Train Episode :17415, Total Frame : 22093156, Train reward : 14.0,
# Train Episode :17416, Total Frame : 22097624, Train reward : 33.0,
# Train Episode :17417, Total Frame : 22100040, Train reward : 18.0,
# Train Episode :17418, Total Frame : 22102516, Train reward : 17.0,
# Train Episode :17419, Total Frame : 22105144, Train reward : 24.0,
# ※Test※ 	 Frames: 4945 	 Score: 40.0
# Train Episode :17420, Total Frame : 22109840, Train reward : 46.0,
# Train Episode :17421, Total Frame : 22114464, Train reward : 42.0,
# Train Episode :17422, Total Frame : 22119268, Train reward : 59.0,
# Update Target
# Train Episode :17423, Total Frame : 22121948, Train reward : 26.0,
# Train Episode :17424, Total Frame : 22124008, Train reward : 22.0,
# Train Episode :17425, Total Frame : 22127784, Train reward : 26.0,
# Train Episode :17426, Total Frame : 22131008, Train reward : 19.0,
# Train Episode :17427, Total Frame : 22133020, Train reward : 17.0,
# Train Episode :17428, Total Frame : 22136860, Train reward : 54.0,
# Train Episode :17429, Total Frame : 22141456, Train reward : 49.0,
# ※Test※ 	 Frames: 4607 	 Score: 42.0
# Train Episode :17430, Total Frame : 22145572, Train reward : 38.0,
# Train Episode :17431, Total Frame : 22149208, Train reward : 39.0,
# Train Episode :17432, Total Frame : 22153632, Train reward : 51.0,
# Train Episode :17433, Total Frame : 22155592, Train reward : 12.0,
# Train Episode :17434, Total Frame : 22158120, Train reward : 19.0,
# Update Target
# ...
# Train Episode :18039, Total Frame : 24313580, Train reward : 27.0,
# ※Test※ 	 Frames: 2866 	 Score: 18.0
# Train Episode :18040, Total Frame : 24317916, Train reward : 248.0,
# Update Target
# Train Episode :18041, Total Frame : 24321568, Train reward : 40.0,
# Train Episode :18042, Total Frame : 24324136, Train reward : 15.0,
# Train Episode :18043, Total Frame : 24328468, Train reward : 59.0,
# Train Episode :18044, Total Frame : 24332752, Train reward : 40.0,
# Train Episode :18045, Total Frame : 24336184, Train reward : 27.0,
# Train Episode :18046, Total Frame : 24340236, Train reward : 246.0,
# Train Episode :18047, Total Frame : 24345528, Train reward : 52.0,
# Train Episode :18048, Total Frame : 24350132, Train reward : 38.0,
# Train Episode :18049, Total Frame : 24354248, Train reward : 70.0,
# ※Test※ 	 Frames: 3992 	 Score: 34.0
# Train Episode :18050, Total Frame : 24358352, Train reward : 42.0,
# Update Target
# Train Episode :18051, Total Frame : 24362716, Train reward : 61.0,
# Train Episode :18052, Total Frame : 24367408, Train reward : 47.0,
# Train Episode :18053, Total Frame : 24370600, Train reward : 31.0,
# Train Episode :18054, Total Frame : 24373760, Train reward : 26.0,
# Train Episode :18055, Total Frame : 24378660, Train reward : 52.0,
# Train Episode :18056, Total Frame : 24382772, Train reward : 46.0,
# Train Episode :18057, Total Frame : 24387504, Train reward : 48.0,
# Train Episode :18058, Total Frame : 24391668, Train reward : 37.0,
# Train Episode :18059, Total Frame : 24395320, Train reward : 48.0,
# ※Test※ 	 Frames: 6402 	 Score: 67.0
# Train Episode :18060, Total Frame : 24398184, Train reward : 24.0,
# Update Target
# Train Episode :18061, Total Frame : 24401216, Train reward : 69.0,
# Train Episode :18062, Total Frame : 24405684, Train reward : 56.0,
# Train Episode :18063, Total Frame : 24409588, Train reward : 37.0,
# Train Episode :18064, Total Frame : 24412520, Train reward : 21.0,
# Train Episode :18065, Total Frame : 24415172, Train reward : 42.0,
# Train Episode :18066, Total Frame : 24418436, Train reward : 31.0,
# Train Episode :18067, Total Frame : 24421864, Train reward : 26.0,
# Train Episode :18068, Total Frame : 24425832, Train reward : 31.0,
# Train Episode :18069, Total Frame : 24429148, Train reward : 19.0,
# ※Test※ 	 Frames: 1835 	 Score: 20.0
# Train Episode :18070, Total Frame : 24433176, Train reward : 62.0,
# Train Episode :18071, Total Frame : 24437260, Train reward : 29.0,
# Update Target
# Train Episode :18072, Total Frame : 24440940, Train reward : 36.0,
# Train Episode :18073, Total Frame : 24443720, Train reward : 24.0,
# Train Episode :18074, Total Frame : 24448744, Train reward : 54.0,
# Train Episode :18075, Total Frame : 24453684, Train reward : 58.0,
# Train Episode :18076, Total Frame : 24457752, Train reward : 44.0,
# Train Episode :18077, Total Frame : 24462016, Train reward : 45.0,
# Train Episode :18078, Total Frame : 24466556, Train reward : 49.0,
# Train Episode :18079, Total Frame : 24470056, Train reward : 47.0,
# ※Test※ 	 Frames: 3083 	 Score: 19.0
# Train Episode :18080, Total Frame : 24473492, Train reward : 29.0,
# Train Episode :18081, Total Frame : 24476304, Train reward : 232.0,
# Update Target
# Train Episode :18082, Total Frame : 24480720, Train reward : 39.0,
# Train Episode :18083, Total Frame : 24484756, Train reward : 37.0,
# Train Episode :18084, Total Frame : 24489452, Train reward : 35.0,
# Train Episode :18085, Total Frame : 24492676, Train reward : 29.0,
# Train Episode :18086, Total Frame : 24495612, Train reward : 22.0,
# Train Episode :18087, Total Frame : 24501708, Train reward : 75.0,
# Train Episode :18088, Total Frame : 24505452, Train reward : 33.0,
# Train Episode :18089, Total Frame : 24508772, Train reward : 30.0,
# ※Test※ 	 Frames: 4838 	 Score: 47.0
# Train Episode :18090, Total Frame : 24512500, Train reward : 31.0,
# Train Episode :18091, Total Frame : 24516600, Train reward : 69.0,
# Update Target
# Train Episode :18092, Total Frame : 24520028, Train reward : 26.0,
# Train Episode :18093, Total Frame : 24522012, Train reward : 12.0,
# Train Episode :18094, Total Frame : 24527520, Train reward : 51.0,
# Train Episode :18095, Total Frame : 24531704, Train reward : 41.0,
# Train Episode :18096, Total Frame : 24533736, Train reward : 15.0,
# Train Episode :18097, Total Frame : 24537284, Train reward : 242.0,
# Train Episode :18098, Total Frame : 24540532, Train reward : 29.0,
# Train Episode :18099, Total Frame : 24543528, Train reward : 25.0,
# ※Test※ 	 Frames: 3126 	 Score: 41.0
# Train Episode :18100, Total Frame : 24546008, Train reward : 19.0,
# Train Episode :18101, Total Frame : 24550396, Train reward : 30.0,
# Train Episode :18102, Total Frame : 24555080, Train reward : 46.0,
# Train Episode :18103, Total Frame : 24558888, Train reward : 37.0,
# Update Target
# Train Episode :18104, Total Frame : 24561608, Train reward : 16.0,
# Train Episode :18105, Total Frame : 24564484, Train reward : 25.0,
# Train Episode :18106, Total Frame : 24568664, Train reward : 41.0,
# Train Episode :18107, Total Frame : 24573192, Train reward : 54.0,
# Train Episode :18108, Total Frame : 24575968, Train reward : 29.0,
# Train Episode :18109, Total Frame : 24579528, Train reward : 33.0,
# ※Test※ 	 Frames: 4243 	 Score: 43.0
# Train Episode :18110, Total Frame : 24583492, Train reward : 27.0,
# Train Episode :18111, Total Frame : 24587772, Train reward : 263.0,
# Train Episode :18112, Total Frame : 24591612, Train reward : 38.0,
# Train Episode :18113, Total Frame : 24594608, Train reward : 23.0,
# Train Episode :18114, Total Frame : 24598336, Train reward : 33.0,
# Update Target
# Train Episode :18115, Total Frame : 24603268, Train reward : 57.0,
# Train Episode :18116, Total Frame : 24607700, Train reward : 70.0,
# Train Episode :18117, Total Frame : 24613336, Train reward : 184.0,
# Train Episode :18118, Total Frame : 24616732, Train reward : 40.0,
# Train Episode :18119, Total Frame : 24621148, Train reward : 42.0,
# ※Test※ 	 Frames: 5169 	 Score: 58.0
# Train Episode :18120, Total Frame : 24625576, Train reward : 252.0,
# Train Episode :18121, Total Frame : 24630160, Train reward : 46.0,
# Train Episode :18122, Total Frame : 24633728, Train reward : 24.0,
# Train Episode :18123, Total Frame : 24638124, Train reward : 248.0,
# Update Target
# Train Episode :18124, Total Frame : 24641844, Train reward : 37.0,
# Train Episode :18125, Total Frame : 24644712, Train reward : 35.0,
# Train Episode :18126, Total Frame : 24648548, Train reward : 37.0,
# Train Episode :18127, Total Frame : 24653416, Train reward : 62.0,
# Train Episode :18128, Total Frame : 24657864, Train reward : 39.0,
# Train Episode :18129, Total Frame : 24661788, Train reward : 35.0,
# ※Test※ 	 Frames: 4969 	 Score: 55.0
# Train Episode :18130, Total Frame : 24668172, Train reward : 67.0,
# Train Episode :18131, Total Frame : 24673148, Train reward : 51.0,
# Train Episode :18132, Total Frame : 24676296, Train reward : 27.0,
# Train Episode :18133, Total Frame : 24679672, Train reward : 55.0,
# Update Target
# Train Episode :18134, Total Frame : 24682624, Train reward : 25.0,
# Train Episode :18135, Total Frame : 24687024, Train reward : 45.0,
# Train Episode :18136, Total Frame : 24692056, Train reward : 59.0,
# Train Episode :18137, Total Frame : 24696224, Train reward : 54.0,
# Train Episode :18138, Total Frame : 24700112, Train reward : 57.0,
# Train Episode :18139, Total Frame : 24704424, Train reward : 35.0,
# ※Test※ 	 Frames: 4377 	 Score: 44.0
# Train Episode :18140, Total Frame : 24707596, Train reward : 42.0,
# Train Episode :18141, Total Frame : 24711856, Train reward : 41.0,
# Train Episode :18142, Total Frame : 24715024, Train reward : 29.0,
# Train Episode :18143, Total Frame : 24718888, Train reward : 29.0,
# Update Target
# Train Episode :18144, Total Frame : 24721660, Train reward : 44.0,
# Train Episode :18145, Total Frame : 24725764, Train reward : 43.0,
# Train Episode :18146, Total Frame : 24730472, Train reward : 49.0,
# Train Episode :18147, Total Frame : 24733272, Train reward : 24.0,
# Train Episode :18148, Total Frame : 24736484, Train reward : 26.0,
# Train Episode :18149, Total Frame : 24740808, Train reward : 41.0,
# ※Test※ 	 Frames: 2494 	 Score: 22.0
# Train Episode :18150, Total Frame : 24745340, Train reward : 39.0,
# Train Episode :18151, Total Frame : 24748888, Train reward : 26.0,
# Train Episode :18152, Total Frame : 24751520, Train reward : 27.0,
# Train Episode :18153, Total Frame : 24757048, Train reward : 382.0,
# Update Target
# Train Episode :18154, Total Frame : 24761208, Train reward : 351.0,
# Train Episode :18155, Total Frame : 24767424, Train reward : 60.0,
# Train Episode :18156, Total Frame : 24772396, Train reward : 47.0,
# Train Episode :18157, Total Frame : 24777628, Train reward : 255.0,
# Train Episode :18158, Total Frame : 24782716, Train reward : 56.0,
# Train Episode :18159, Total Frame : 24787068, Train reward : 58.0,
# ※Test※ 	 Frames: 4892 	 Score: 50.0
# Train Episode :18160, Total Frame : 24792092, Train reward : 61.0,
# Train Episode :18161, Total Frame : 24796280, Train reward : 46.0,
# Update Target
# Train Episode :18162, Total Frame : 24800556, Train reward : 52.0,
# Train Episode :18163, Total Frame : 24806304, Train reward : 80.0,
# Train Episode :18164, Total Frame : 24811468, Train reward : 49.0,
# Train Episode :18165, Total Frame : 24815300, Train reward : 26.0,
# Train Episode :18166, Total Frame : 24818180, Train reward : 220.0,
# Train Episode :18167, Total Frame : 24821876, Train reward : 42.0,
# Train Episode :18168, Total Frame : 24825240, Train reward : 24.0,
# Train Episode :18169, Total Frame : 24828964, Train reward : 45.0,
# ※Test※ 	 Frames: 2603 	 Score: 19.0
# Train Episode :18170, Total Frame : 24833880, Train reward : 254.0,
# Train Episode :18171, Total Frame : 24837304, Train reward : 24.0,
# Train Episode :18172, Total Frame : 24839488, Train reward : 26.0,
# Update Target
# Train Episode :18173, Total Frame : 24841904, Train reward : 35.0,
# Train Episode :18174, Total Frame : 24846392, Train reward : 32.0,
# Train Episode :18175, Total Frame : 24851340, Train reward : 42.0,
# Train Episode :18176, Total Frame : 24854524, Train reward : 21.0,
# Train Episode :18177, Total Frame : 24857760, Train reward : 29.0,
# Train Episode :18178, Total Frame : 24861348, Train reward : 22.0,
# Train Episode :18179, Total Frame : 24864768, Train reward : 28.0,
# ※Test※ 	 Frames: 3752 	 Score: 32.0
# Train Episode :18180, Total Frame : 24869052, Train reward : 39.0,
# Train Episode :18181, Total Frame : 24872792, Train reward : 49.0,
# Train Episode :18182, Total Frame : 24878936, Train reward : 277.0,
# Update Target
# Train Episode :18183, Total Frame : 24882412, Train reward : 41.0,
# Train Episode :18184, Total Frame : 24884620, Train reward : 21.0,
# Train Episode :18185, Total Frame : 24889144, Train reward : 63.0,
# Train Episode :18186, Total Frame : 24894072, Train reward : 53.0,
# Train Episode :18187, Total Frame : 24898004, Train reward : 34.0,
# Train Episode :18188, Total Frame : 24902992, Train reward : 38.0,
# Train Episode :18189, Total Frame : 24905784, Train reward : 24.0,
# ※Test※ 	 Frames: 3647 	 Score: 49.0
# Train Episode :18190, Total Frame : 24909700, Train reward : 354.0,
# Train Episode :18191, Total Frame : 24912732, Train reward : 32.0,
# Train Episode :18192, Total Frame : 24917776, Train reward : 46.0,
# Update Target
# Train Episode :18193, Total Frame : 24921516, Train reward : 24.0,
# Train Episode :18194, Total Frame : 24924760, Train reward : 30.0,
# Train Episode :18195, Total Frame : 24926916, Train reward : 32.0,
# Train Episode :18196, Total Frame : 24931904, Train reward : 57.0,
# Train Episode :18197, Total Frame : 24934904, Train reward : 36.0,
# Train Episode :18198, Total Frame : 24939220, Train reward : 50.0,
# Train Episode :18199, Total Frame : 24943656, Train reward : 38.0,
# ※Test※ 	 Frames: 4250 	 Score: 44.0
# Train Episode :18200, Total Frame : 24946972, Train reward : 24.0,
# Train Episode :18201, Total Frame : 24951980, Train reward : 48.0,
# Train Episode :18202, Total Frame : 24956936, Train reward : 51.0,
# Update Target
# Train Episode :18203, Total Frame : 24962536, Train reward : 64.0,
# Train Episode :18204, Total Frame : 24964900, Train reward : 21.0,
# Train Episode :18205, Total Frame : 24967652, Train reward : 16.0,
# Train Episode :18206, Total Frame : 24969764, Train reward : 17.0,
# Train Episode :18207, Total Frame : 24973964, Train reward : 34.0,
# Train Episode :18208, Total Frame : 24978276, Train reward : 41.0,
# Train Episode :18209, Total Frame : 24982540, Train reward : 29.0,
# ※Test※ 	 Frames: 4588 	 Score: 76.0
# Train Episode :18210, Total Frame : 24987864, Train reward : 57.0,
# Train Episode :18211, Total Frame : 24992044, Train reward : 42.0,
# Train Episode :18212, Total Frame : 24995644, Train reward : 31.0,
# Train Episode :18213, Total Frame : 24998388, Train reward : 51.0,
# Update Target
# Train Episode :18214, Total Frame : 25001188, Train reward : 27.0,
# Train Episode :18215, Total Frame : 25004568, Train reward : 47.0,
# Train Episode :18216, Total Frame : 25007984, Train reward : 62.0,
# Train Episode :18217, Total Frame : 25011748, Train reward : 52.0,
# Train Episode :18218, Total Frame : 25015176, Train reward : 27.0,
# Train Episode :18219, Total Frame : 25019056, Train reward : 32.0,
# ※Test※ 	 Frames: 6144 	 Score: 65.0
# Train Episode :18220, Total Frame : 25022676, Train reward : 29.0,
# Train Episode :18221, Total Frame : 25026884, Train reward : 43.0,
# Train Episode :18222, Total Frame : 25029756, Train reward : 30.0,
# Train Episode :18223, Total Frame : 25033936, Train reward : 39.0,
# Train Episode :18224, Total Frame : 25035788, Train reward : 13.0,
# Update Target
# Train Episode :18225, Total Frame : 25041368, Train reward : 51.0,
# Train Episode :18226, Total Frame : 25044324, Train reward : 39.0,
# Train Episode :18227, Total Frame : 25047660, Train reward : 30.0,
# Train Episode :18228, Total Frame : 25051104, Train reward : 32.0,
# Train Episode :18229, Total Frame : 25055100, Train reward : 32.0,
# ※Test※ 	 Frames: 4348 	 Score: 40.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-d7039d1ee483> in <module>
#       1 max_frame = 50000000
# ----> 2 fitter.train(max_frame)
#
# <ipython-input-12-e6afa02e78c0> in train(self, max_total_frame)
#     100                 # training when enough replay-memory, every k-frames
#     101                 if len(self.replay_memory) > self.min_replay:
# --> 102                     self.train_batch(self.batch_size)
#     103                     self.total_frame += self.k
#     104
#
# <ipython-input-12-e6afa02e78c0> in train_batch(self, batch_size)
#     140             next_actions = torch.argmax(self.behavior_net(S_next), dim=1) # choose argmax behavior actions at S_next
#     141
# --> 142             q_targets_next = self.target_net(S_next) # cal Q-values of every possible actions next state (targetDQN)
#     143             q_target_next = self.select_indices(q_targets_next, next_actions) # select Q-value for next behavior actions
#     144             q_target = R + self.gamma*q_target_next*(1-D)
#
# ~/anaconda3/envs/tf2/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-9-9a7b14f3fd0c> in forward(self, frames)
#      30
#      31     def forward(self, frames):
# ---> 32         frames = self.prep_for_input(frames)
#      33         conved = self.conv(frames)
#      34         conved = conved.view(conved.size(0), -1)
#
# <ipython-input-9-9a7b14f3fd0c> in prep_for_input(self, img)
#      23
#      24     def prep_for_input(self, img):
# ---> 25         img = torch.tensor(img, dtype=torch.float32, device=self.device).cuda(non_blocking=True) # to tensor
#      26         img /= 255                                   # normalize into 0-1
#      27         while img.dim() < 4 :                        # 4-dim
#
# KeyboardInterrupt:

# %%
plt.plot(fitter.train_reward_ls)

# %%
plt.plot(fitter.test_reward_ls)

# %%
from collections import Counter

ls = []
S_ls = []
for _ in range(100):
    S = fitter.replay_memory.sample(1)[0][0]
    print(fitter.behavior_net(S).data)
    #print(fitter.behavior_net(S).argmax().item())
    ls.append(fitter.behavior_net(S).argmax().item())
    #plt.imshow(S[3])
plt.imshow(S[0])
Counter(ls)
# Out:
# tensor([[1.6754, 1.6699, 1.6922, 1.6503]], device='cuda:0')
# tensor([[1.2831, 1.2908, 1.2606, 1.2689]], device='cuda:0')
# tensor([[1.1201, 1.1339, 1.1096, 1.0906]], device='cuda:0')
# tensor([[1.5316, 1.5217, 1.5004, 1.5350]], device='cuda:0')
# tensor([[1.6372, 1.6461, 1.5247, 1.5132]], device='cuda:0')
# tensor([[1.6783, 1.6824, 1.7009, 1.6588]], device='cuda:0')
# tensor([[1.4375, 1.4437, 1.4368, 1.4534]], device='cuda:0')
# tensor([[1.0568, 1.0497, 1.0455, 1.0067]], device='cuda:0')
# tensor([[1.0910, 1.0943, 1.0704, 1.0771]], device='cuda:0')
# tensor([[1.5826, 1.5645, 1.5813, 1.5245]], device='cuda:0')
# tensor([[1.1219, 1.1362, 1.1314, 1.1263]], device='cuda:0')
# tensor([[1.4739, 1.4624, 1.4644, 1.4480]], device='cuda:0')
# tensor([[1.5686, 1.5772, 1.5747, 1.5559]], device='cuda:0')
# tensor([[1.1561, 1.1637, 1.1285, 1.1332]], device='cuda:0')
# tensor([[0.9199, 0.9165, 0.9407, 0.9190]], device='cuda:0')
# tensor([[1.4630, 1.4793, 1.5072, 1.4529]], device='cuda:0')
# tensor([[1.7556, 1.7584, 1.7375, 1.7360]], device='cuda:0')
# tensor([[1.7626, 1.7477, 1.7663, 1.7681]], device='cuda:0')
# tensor([[0.7101, 0.7093, 0.7165, 0.6999]], device='cuda:0')
# tensor([[0.8203, 0.8250, 0.8288, 0.8054]], device='cuda:0')
# tensor([[1.0724, 1.0773, 1.0544, 1.0694]], device='cuda:0')
# tensor([[1.3484, 1.3485, 1.3257, 1.3115]], device='cuda:0')
# tensor([[0.7534, 0.7740, 0.7244, 0.7511]], device='cuda:0')
# tensor([[1.6502, 1.6708, 1.6656, 1.6490]], device='cuda:0')
# tensor([[0.7774, 0.7838, 0.7790, 0.7557]], device='cuda:0')
# tensor([[1.5234, 1.4781, 1.5001, 1.4815]], device='cuda:0')
# tensor([[1.1894, 1.1941, 1.1856, 1.1648]], device='cuda:0')
# tensor([[1.4505, 1.4546, 1.4639, 1.4480]], device='cuda:0')
# tensor([[1.4413, 1.4470, 1.4712, 1.4483]], device='cuda:0')
# tensor([[0.7573, 0.7433, 0.7570, 0.7586]], device='cuda:0')
# tensor([[0.8024, 0.7893, 0.7907, 0.8072]], device='cuda:0')
# tensor([[1.7047, 1.6830, 1.6383, 1.6209]], device='cuda:0')
# tensor([[1.2158, 1.2069, 1.2147, 1.2223]], device='cuda:0')
# tensor([[0.8141, 0.8204, 0.8264, 0.8355]], device='cuda:0')
# tensor([[1.5239, 1.5205, 1.5221, 1.5101]], device='cuda:0')
# tensor([[1.2986, 1.2875, 1.2972, 1.3153]], device='cuda:0')
# tensor([[0.9309, 0.8833, 0.8693, 0.9090]], device='cuda:0')
# tensor([[1.8201, 1.8460, 1.7963, 1.8283]], device='cuda:0')
# tensor([[1.1504, 1.1544, 1.1394, 1.1578]], device='cuda:0')
# tensor([[2.1262, 2.1368, 2.1096, 2.1288]], device='cuda:0')
# tensor([[1.3024, 1.3068, 1.2779, 1.2706]], device='cuda:0')
# tensor([[1.4570, 1.4534, 1.4291, 1.4593]], device='cuda:0')
# tensor([[0.9953, 0.9960, 1.0061, 0.9626]], device='cuda:0')
# tensor([[1.6581, 1.6699, 1.6301, 1.6770]], device='cuda:0')
# tensor([[0.7443, 0.7396, 0.7647, 0.7381]], device='cuda:0')
# tensor([[1.5369, 1.5620, 1.5585, 1.5316]], device='cuda:0')
# tensor([[1.1158, 1.1213, 1.1180, 1.1066]], device='cuda:0')
# tensor([[1.1634, 1.1648, 1.1497, 1.1555]], device='cuda:0')
# tensor([[1.2758, 1.2646, 1.2431, 1.2539]], device='cuda:0')
# tensor([[0.6348, 0.6291, 0.6224, 0.6067]], device='cuda:0')
# tensor([[0.8018, 0.8183, 0.8254, 0.8236]], device='cuda:0')
# tensor([[0.7516, 0.7355, 0.7527, 0.7361]], device='cuda:0')
# tensor([[0.9195, 0.9193, 0.9297, 0.9106]], device='cuda:0')
# tensor([[1.9587, 1.9689, 1.9696, 1.9512]], device='cuda:0')
# tensor([[0.6238, 0.6596, 0.6637, 0.6315]], device='cuda:0')
# tensor([[1.8131, 1.8133, 1.7834, 1.7660]], device='cuda:0')
# tensor([[1.6523, 1.6574, 1.6654, 1.6632]], device='cuda:0')
# tensor([[1.7668, 1.7811, 1.8074, 1.7658]], device='cuda:0')
# tensor([[1.7489, 1.7374, 1.8150, 1.7357]], device='cuda:0')
# tensor([[0.9732, 0.9466, 0.9538, 0.9663]], device='cuda:0')
# tensor([[1.1716, 1.1743, 1.1569, 1.1447]], device='cuda:0')
# tensor([[2.1412, 2.1047, 2.0736, 2.1123]], device='cuda:0')
# tensor([[1.1087, 1.1229, 1.0876, 1.0777]], device='cuda:0')
# tensor([[1.9861, 1.9740, 2.0124, 1.9687]], device='cuda:0')
# tensor([[1.6681, 1.6717, 1.5944, 1.6054]], device='cuda:0')
# tensor([[1.1919, 1.1963, 1.1385, 1.1518]], device='cuda:0')
# tensor([[1.9033, 1.8970, 1.8978, 1.8724]], device='cuda:0')
# tensor([[1.1031, 1.0747, 1.0868, 1.0911]], device='cuda:0')
# tensor([[1.4616, 1.4426, 1.4539, 1.4266]], device='cuda:0')
# tensor([[1.3520, 1.3480, 1.2649, 1.2392]], device='cuda:0')
# tensor([[0.7271, 0.7312, 0.7477, 0.7199]], device='cuda:0')
# tensor([[0.7667, 0.7885, 0.7485, 0.7728]], device='cuda:0')
# tensor([[1.2369, 1.2586, 1.2482, 1.2268]], device='cuda:0')
# tensor([[1.0845, 1.0881, 1.1068, 1.0748]], device='cuda:0')
# tensor([[1.4007, 1.4196, 1.4284, 1.4104]], device='cuda:0')
# tensor([[0.8912, 0.8906, 0.9073, 0.8762]], device='cuda:0')
# tensor([[1.6032, 1.6223, 1.6200, 1.6266]], device='cuda:0')
# tensor([[1.6702, 1.6633, 1.6376, 1.6237]], device='cuda:0')
# tensor([[1.1228, 1.1175, 1.1382, 1.1113]], device='cuda:0')
# tensor([[1.4807, 1.4858, 1.4949, 1.4555]], device='cuda:0')
# tensor([[1.7479, 1.7363, 1.7443, 1.7240]], device='cuda:0')
# tensor([[1.1133, 1.1217, 1.1143, 1.1069]], device='cuda:0')
# tensor([[1.1269, 1.1216, 1.1894, 1.1170]], device='cuda:0')
# tensor([[0.6930, 0.7226, 0.7244, 0.6951]], device='cuda:0')
# tensor([[0.8632, 0.8743, 0.8690, 0.8515]], device='cuda:0')
# tensor([[1.7116, 1.7011, 1.7389, 1.7234]], device='cuda:0')
# tensor([[1.3961, 1.3922, 1.3112, 1.3157]], device='cuda:0')
# tensor([[0.7802, 0.7806, 0.7714, 0.7655]], device='cuda:0')
# tensor([[1.1921, 1.1979, 1.2128, 1.1830]], device='cuda:0')
# tensor([[1.4221, 1.4238, 1.4308, 1.3928]], device='cuda:0')
# tensor([[1.7328, 1.7319, 1.7479, 1.7402]], device='cuda:0')
# tensor([[1.6522, 1.7219, 1.7165, 1.6690]], device='cuda:0')
# tensor([[1.5143, 1.5180, 1.5130, 1.5318]], device='cuda:0')
# tensor([[1.5941, 1.6025, 1.4752, 1.4572]], device='cuda:0')
# tensor([[1.6385, 1.6111, 1.6252, 1.6376]], device='cuda:0')
# tensor([[1.7363, 1.7243, 1.7397, 1.6803]], device='cuda:0')
# tensor([[0.9415, 0.9484, 0.9846, 0.9375]], device='cuda:0')
# tensor([[1.3549, 1.3863, 1.3609, 1.3487]], device='cuda:0')
# tensor([[1.8059, 1.8042, 1.8254, 1.8090]], device='cuda:0')
# tensor([[1.3759, 1.3727, 1.3943, 1.3729]], device='cuda:0')
# Counter({2: 35, 1: 33, 3: 13, 0: 19})

# %%
plt.imshow(fitter.replay_memory.sample(1)[0][0][0])
